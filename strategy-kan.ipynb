# %% [markdown]
# # Xu-Net

# %% [markdown]
# ## Libraries

# %%
import numpy
import numpy as np
import random
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from keras.layers import Activation
import tensorflow as tf
import cv2
from tensorflow.keras.layers import Lambda, Layer, ReLU
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, LSTM, SpatialDropout2D, Concatenate
tf.keras.layers.Concatenate()
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, UpSampling2D, BatchNormalization
from keras.layers.core import Reshape
from keras import optimizers
from tensorflow.keras import regularizers
from keras import Input, Model
from time import time
import time as tm
from keras.initializers import Constant, RandomNormal, glorot_normal
from tensorflow.keras.models import load_model
from tensorflow.keras.regularizers import l2
from keras import backend as K
from tensorflow.keras.utils import plot_model
from keras.layers import  concatenate

from tfkan.layers import DenseKAN
from tfkan.layers import Conv2DKAN
from tfkan.layers import base

# %% [markdown]
# ## 30 SRM filters for preprocessing and the activation function

# %%
################################################## 30 SRM FILTERS
srm_weights = np.load('SRM_Kernels.npy') 
biasSRM=numpy.ones(30)
print (srm_weights.shape)
################################################## TLU ACTIVATION FUNCTION
T3 = 3;
def Tanh3(x):
    tanh3 = K.tanh(x)*T3
    return tanh3
##################################################
# Out:
# (5, 5, 1, 30)

# %% [markdown]
# ## Functions

# %%
## DCT filters function

def make_DCT_filter():
    with tf.name_scope("DCT"):
        # Initialize DCT filters
        DCT_filter_n = np.zeros([5, 5, 1, 64])
        # Definition of 8x8 mesh grid
        XX, YY = np.meshgrid(range(5), range(5))
        # DCT basis as filters
        C=np.ones(5)
        C[0]=1/np.sqrt(2)
        for v in range(5):
            for u in range(5):
                DCT_filter_n[:, :, 0, u+v*5]=(2*C[v]*C[u]/5)*np.cos((2*YY+1)*v*np.pi/(10))*np.cos((2*XX+1)*u*np.pi/(10))

        DCT_filter=tf.constant(DCT_filter_n.astype(np.float32))

        return DCT_filter

def Fun(x):
    fun = tf.keras.activations.hard_sigmoid(x)*3
    return fun

def squeeze_excitation_layer(input_layer, out_dim, ratio, conv):
  squeeze = tf.keras.layers.GlobalAveragePooling2D()(input_layer)
  excitation = tf.keras.layers.Dense(units=out_dim / ratio, activation='relu')(squeeze)
  excitation = tf.keras.layers.Dense(out_dim,activation='sigmoid')(excitation)
  excitation = tf.reshape(excitation, [-1,1,1,out_dim])
  scale = tf.keras.layers.multiply([input_layer, excitation])
  
  if conv:
    shortcut = tf.keras.layers.Conv2D(out_dim,kernel_size=1,strides=1,
                                      padding='same',kernel_initializer='he_normal')(input_layer)
    shortcut = tf.keras.layers.BatchNormalization()(shortcut)
  else:
    shortcut = input_layer
  out = tf.keras.layers.add([shortcut, scale])
  return out

# %% [markdown]
# ## Xu-Net architecture

# %%
def Xu_Net_strategy():
    
    img_size=256
    
    DCT_filter = make_DCT_filter()
    print(DCT_filter.shape)

    filters = np.concatenate([DCT_filter,srm_weights],axis=3)
    filters.shape
    
    bias = np.ones(94)

    tf.keras.backend.clear_session()
    inputs = tf.keras.Input(shape=(img_size,img_size,1), name="input")
    # Layer 1
    #conv0 =   tf.keras.layers.Conv2D(94, (5,5), weights=[filters,bias], strides=(1,1), trainable=False, activation=Tanh3, use_bias=True)(inputs)

    #Block 1
    layers_ty = tf.keras.layers.Conv2D(30, (5,5), weights=[srm_weights,biasSRM], strides=(1,1), trainable=False, padding='same', activation=Tanh3, use_bias=True)(inputs)
    layers_tn = tf.keras.layers.Conv2D(30, (5,5), weights=[srm_weights,biasSRM], strides=(1,1), trainable=True, padding='same', activation=Tanh3, use_bias=True)(inputs)
    layers1 = tf.keras.layers.add([layers_ty, layers_tn])

    layers = tf.keras.layers.Conv2D(30, (1,1), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers1) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
  
    layers = tf.keras.layers.Conv2D(30, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)

    layers = tf.keras.layers.Conv2D(30, (1,1), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    block_squeeze = squeeze_excitation_layer(layers, out_dim=30, ratio=32.0, conv=False)

    layers_Tr_1 = tf.keras.layers.add([layers1, block_squeeze])

    layers = tf.keras.layers.SpatialDropout2D(rate=0.1)(layers_Tr_1)
    layers = Conv2DKAN(30, (3,3), strides=(5,5),padding="same")(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = AveragePooling2D((5,5), strides= 2, padding='same')(layers)

    layers = tf.keras.layers.SpatialDropout2D(rate=0.1)(layers_Tr_1)
    layers = Conv2DKAN(15, (3,3), strides=(5,5),padding="same")(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = AveragePooling2D((5,5), strides= 2, padding='same')(layers)
    
    layers = tf.keras.layers.SpatialDropout2D(rate=0.1)(layers)
    layers = Conv2DKAN(8, (3,3), strides=(1,1),padding="same")(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = AveragePooling2D((5,5), strides= 2, padding='same')(layers)

    layers = tf.keras.layers.SpatialDropout2D(rate=0.1)(layers)
    layers = Conv2DKAN(8, (3,3), strides=(1,1),padding="same")(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    #layers = Concatenate()([layers, layers, layers])
    layers = GlobalAveragePooling2D(data_format="channels_last")(layers)


    #Layer 18
    layers = DenseKAN(2)(layers)
    #Layer 19
    predictions = tf.keras.layers.Softmax(axis=1)(layers)
    model =tf.keras.Model(inputs = inputs, outputs=predictions)

    #Compile
    optimizer = tf.keras.optimizers.SGD(learning_rate=0.005, momentum=0.95)
    
    if compile:
        model.compile(optimizer= optimizer,
                      loss='binary_crossentropy',
                      metrics=['accuracy'])
        print ("kan_model")
    return model

# %%
model = Xu_Net_strategy()
model.summary()
# Out:
# (5, 5, 1, 64)
# kan_model
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 30  780         ['input[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 30  780         ['input[0][0]']
#                                 )
#
#  add (Add)                      (None, 256, 256, 30  0           ['conv2d[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 30  930         ['add[0][0]']
#                                 )
#
#  re_lu (ReLU)                   (None, 256, 256, 30  0           ['conv2d_2[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 30  120        ['re_lu[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 30  8130        ['batch_normalization[0][0]']
#                                 )
#
#  re_lu_1 (ReLU)                 (None, 256, 256, 30  0           ['conv2d_3[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 30  120        ['re_lu_1[0][0]']
#  rmalization)                   )
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 30  930         ['batch_normalization_1[0][0]']
#                                 )
#
#  re_lu_2 (ReLU)                 (None, 256, 256, 30  0           ['conv2d_4[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 30  120        ['re_lu_2[0][0]']
#  rmalization)                   )
#
#  global_average_pooling2d (Glob  (None, 30)          0           ['batch_normalization_2[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 0)            0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 30)           30          ['dense[0][0]']
#
#  tf.reshape (TFOpLambda)        (None, 1, 1, 30)     0           ['dense_1[0][0]']
#
#  multiply (Multiply)            (None, 256, 256, 30  0           ['batch_normalization_2[0][0]',
#                                 )                                 'tf.reshape[0][0]']
#
#  add_1 (Add)                    (None, 256, 256, 30  0           ['batch_normalization_2[0][0]',
#                                 )                                 'multiply[0][0]']
#
#  add_2 (Add)                    (None, 256, 256, 30  0           ['add[0][0]',
#                                 )                                 'add_1[0][0]']
#
#  spatial_dropout2d_1 (SpatialDr  (None, 256, 256, 30  0          ['add_2[0][0]']
#  opout2D)                       )
#
#  conv2dkan_1 (Conv2DKAN)        (None, 128, 128, 15  39705       ['spatial_dropout2d_1[0][0]']
#                                 )
#
#  lambda_1 (Lambda)              (None, 128, 128, 15  0           ['conv2dkan_1[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 15  60         ['lambda_1[0][0]']
#  rmalization)                   )
#
#  average_pooling2d_1 (AveragePo  (None, 64, 64, 15)  0           ['batch_normalization_4[0][0]']
#  oling2D)
#
#  spatial_dropout2d_2 (SpatialDr  (None, 64, 64, 15)  0           ['average_pooling2d_1[0][0]']
#  opout2D)
#
#  conv2dkan_2 (Conv2DKAN)        (None, 64, 64, 8)    11348       ['spatial_dropout2d_2[0][0]']
#
#  lambda_2 (Lambda)              (None, 64, 64, 8)    0           ['conv2dkan_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 8)   32          ['lambda_2[0][0]']
#  rmalization)
#
#  average_pooling2d_2 (AveragePo  (None, 32, 32, 8)   0           ['batch_normalization_5[0][0]']
#  oling2D)
#
#  spatial_dropout2d_3 (SpatialDr  (None, 32, 32, 8)   0           ['average_pooling2d_2[0][0]']
#  opout2D)
#
#  conv2dkan_3 (Conv2DKAN)        (None, 32, 32, 8)    6056        ['spatial_dropout2d_3[0][0]']
#
#  lambda_3 (Lambda)              (None, 32, 32, 8)    0           ['conv2dkan_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 8)   32          ['lambda_3[0][0]']
#  rmalization)
#
#  global_average_pooling2d_1 (Gl  (None, 8)           0           ['batch_normalization_6[0][0]']
#  obalAveragePooling2D)
#
#  dense_kan (DenseKAN)           (None, 2)            242         ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  softmax (Softmax)              (None, 2)            0           ['dense_kan[0][0]']
#
# ==================================================================================================
# Total params: 69,415
# Trainable params: 62,573
# Non-trainable params: 6,842
# __________________________________________________________________________________________________

# %% [markdown]
# ## Defining different functions to work with the architecture

# %%
def train(model, X_train, y_train, X_valid, y_valid, X_test, y_test, batch_size, epochs, initial_epoch = 0, model_name="", num_test=""):
    start_time = tm.time()
    log_dir="D:/testing_"+num_test+"/"+model_name+"_"+"{}".format(time())
    tensorboard = tf.keras.callbacks.TensorBoard(log_dir)
    filepath = log_dir+"/saved-model.hdf5"
    checkpoint = tf.keras.callbacks.ModelCheckpoint(
        filepath, 
        monitor='val_accuracy', 
        save_best_only=True, 
        mode='max',
        verbose=1
    )
    model.reset_states()
    history=model.fit(X_train, y_train, epochs=epochs, 
                        callbacks=[tensorboard,  checkpoint], 
                        batch_size=batch_size,
                        validation_data=(X_valid, y_valid),
                        initial_epoch=initial_epoch)
    
    metrics = model.evaluate(X_test, y_test, verbose=0)
    results_dir="D:/testing_"+num_test+"/"+model_name+"/"
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
      
        plt.figure(figsize=(10, 10))
        #plt.subplot(1,2,1)
        #Plot training & validation accuracy values
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('Accuracy Vs Epochs')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.grid('on')
        plt.savefig(results_dir+'Accuracy_Xu_Net_'+model_name+'.eps', format='eps')
        plt.savefig(results_dir+'Accuracy_Xu_Net_'+model_name+'.svg', format='svg')
        plt.savefig(results_dir+'Accuracy_Xu_Net_'+model_name+'.pdf', format='pdf')
        plt.show()
        
        plt.figure(figsize=(10, 10))
        #plt.subplot(1,2,2)
        #Plot training & validation loss values
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('Loss Vs Epochs')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.grid('on')
        plt.savefig(results_dir+'Loss_Xu_Net_'+model_name+'.eps', format='eps')
        plt.savefig(results_dir+'Loss_Xu_Net_'+model_name+'.svg', format='svg')
        plt.savefig(results_dir+'Loss_Xu_Net_'+model_name+'.pdf', format='pdf')
        plt.show()

    TIME = tm.time() - start_time
    print("Time "+model_name+" = %s [seconds]" % TIME)
    return {k:v for k,v in zip (model.metrics_names, metrics)}

# %%
def Final_Results_Test(model,filename):

    if filename != ('train') and filename != ('validation'):
        print("\n\nBest")
        print(filename)
        model.load_weights(filename)
        loss,accuracy = model.evaluate(X_test, y_test,verbose=0)
        print(f'Loss={loss:.4f} y Accuracy={accuracy:0.4f}'+'\n')

# %% [markdown]
# ## Working with BOSSbase 1.01 WOW y PAYLOAD = 0.4bpp

# %% [markdown]
# In the README, there is a link to download the databases we use for the work. There are two databases BOSSbase 1.01 and Bows2+ BOSSbase 1.01, cover images and stego. You can choose the payload of 0.2 and 0.4 bpp for each of the databases.

# %%
#Train
X_train = np.load('data_load\X_train.npy')
y_train = np.load('data_load\y_train.npy')
#Valid
X_valid = np.load('data_load\X_valid.npy')
y_valid = np.load('data_load\y_valid.npy')
#Test
X_test = np.load('data_load\X_test.npy')
y_test = np.load('data_load\y_test.npy')

print(X_train.shape)
print(y_train.shape)
print(X_valid.shape)
print(y_valid.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (8000, 256, 256, 1)
# (8000, 2)
# (2000, 256, 256, 1)
# (2000, 2)
# (10000, 256, 256, 1)
# (10000, 2)

# %% [markdown]
# ## CNN name and algorithm

# %%
base_name="04S-UNIWARD"
m_name="kan_strategy"

# %% [markdown]
# ## Training

# %%
model= Xu_Net_strategy() 
name="Model_"+m_name+"_"+base_name
_, history  = train(model, X_train, y_train, X_valid, y_valid, X_test, y_test, batch_size=4, epochs=200, model_name=name, num_test='1')
# Out:
# (5, 5, 1, 64)
# kan_model
# Epoch 1/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7075 - accuracy: 0.5074
# Epoch 1: val_accuracy improved from -inf to 0.49700, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 187s 91ms/step - loss: 0.7075 - accuracy: 0.5074 - val_loss: 0.7360 - val_accuracy: 0.4970
# Epoch 2/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7066 - accuracy: 0.4934
# Epoch 2: val_accuracy improved from 0.49700 to 0.50000, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 181s 91ms/step - loss: 0.7066 - accuracy: 0.4934 - val_loss: 0.7432 - val_accuracy: 0.5000
# Epoch 3/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7045 - accuracy: 0.5050
# Epoch 3: val_accuracy did not improve from 0.50000
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.7045 - accuracy: 0.5050 - val_loss: 0.7070 - val_accuracy: 0.5000
# Epoch 4/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7034 - accuracy: 0.5063
# Epoch 4: val_accuracy improved from 0.50000 to 0.52500, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 179s 89ms/step - loss: 0.7034 - accuracy: 0.5063 - val_loss: 0.7176 - val_accuracy: 0.5250
# Epoch 5/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7039 - accuracy: 0.4929
# Epoch 5: val_accuracy did not improve from 0.52500
# 2000/2000 [==============================] - 179s 89ms/step - loss: 0.7039 - accuracy: 0.4929 - val_loss: 0.7033 - val_accuracy: 0.5130
# Epoch 6/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7028 - accuracy: 0.5030
# Epoch 6: val_accuracy did not improve from 0.52500
# 2000/2000 [==============================] - 183s 91ms/step - loss: 0.7028 - accuracy: 0.5030 - val_loss: 0.6979 - val_accuracy: 0.5135
# Epoch 7/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7019 - accuracy: 0.5001
# Epoch 7: val_accuracy did not improve from 0.52500
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.7019 - accuracy: 0.5001 - val_loss: 0.7121 - val_accuracy: 0.5200
# Epoch 8/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6997 - accuracy: 0.5105
# Epoch 8: val_accuracy did not improve from 0.52500
# 2000/2000 [==============================] - 171s 86ms/step - loss: 0.6997 - accuracy: 0.5105 - val_loss: 0.7080 - val_accuracy: 0.5210
# Epoch 9/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7014 - accuracy: 0.4933
# Epoch 9: val_accuracy did not improve from 0.52500
# 2000/2000 [==============================] - 180s 90ms/step - loss: 0.7014 - accuracy: 0.4933 - val_loss: 0.6987 - val_accuracy: 0.5000
# Epoch 10/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7009 - accuracy: 0.5017
# Epoch 10: val_accuracy did not improve from 0.52500
# 2000/2000 [==============================] - 179s 90ms/step - loss: 0.7009 - accuracy: 0.5017 - val_loss: 0.7143 - val_accuracy: 0.5000
# Epoch 11/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6976 - accuracy: 0.5153
# Epoch 11: val_accuracy did not improve from 0.52500
# 2000/2000 [==============================] - 171s 86ms/step - loss: 0.6976 - accuracy: 0.5153 - val_loss: 0.7063 - val_accuracy: 0.5170
# Epoch 12/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6990 - accuracy: 0.5134
# Epoch 12: val_accuracy did not improve from 0.52500
# 2000/2000 [==============================] - 171s 86ms/step - loss: 0.6990 - accuracy: 0.5134 - val_loss: 0.7091 - val_accuracy: 0.5000
# Epoch 13/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6986 - accuracy: 0.5063
# Epoch 13: val_accuracy improved from 0.52500 to 0.53650, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 173s 86ms/step - loss: 0.6986 - accuracy: 0.5063 - val_loss: 0.7149 - val_accuracy: 0.5365
# Epoch 14/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6972 - accuracy: 0.5142
# Epoch 14: val_accuracy did not improve from 0.53650
# 2000/2000 [==============================] - 175s 88ms/step - loss: 0.6972 - accuracy: 0.5142 - val_loss: 0.7232 - val_accuracy: 0.5000
# Epoch 15/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6972 - accuracy: 0.5116
# Epoch 15: val_accuracy did not improve from 0.53650
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6972 - accuracy: 0.5116 - val_loss: 0.6942 - val_accuracy: 0.5310
# Epoch 16/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6976 - accuracy: 0.5045
# Epoch 16: val_accuracy did not improve from 0.53650
# 2000/2000 [==============================] - 181s 90ms/step - loss: 0.6976 - accuracy: 0.5045 - val_loss: 0.6939 - val_accuracy: 0.5260
# Epoch 17/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6972 - accuracy: 0.5166
# Epoch 17: val_accuracy did not improve from 0.53650
# 2000/2000 [==============================] - 183s 91ms/step - loss: 0.6972 - accuracy: 0.5166 - val_loss: 0.7069 - val_accuracy: 0.5000
# Epoch 18/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6973 - accuracy: 0.5180
# Epoch 18: val_accuracy did not improve from 0.53650
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6973 - accuracy: 0.5180 - val_loss: 0.6930 - val_accuracy: 0.5260
# Epoch 19/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6950 - accuracy: 0.5255
# Epoch 19: val_accuracy improved from 0.53650 to 0.54750, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 180s 90ms/step - loss: 0.6950 - accuracy: 0.5255 - val_loss: 0.6895 - val_accuracy: 0.5475
# Epoch 20/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6969 - accuracy: 0.5088
# Epoch 20: val_accuracy did not improve from 0.54750
# 2000/2000 [==============================] - 174s 87ms/step - loss: 0.6969 - accuracy: 0.5088 - val_loss: 0.6985 - val_accuracy: 0.5000
# Epoch 21/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6963 - accuracy: 0.5159
# Epoch 21: val_accuracy did not improve from 0.54750
# 2000/2000 [==============================] - 172s 86ms/step - loss: 0.6963 - accuracy: 0.5159 - val_loss: 0.7561 - val_accuracy: 0.5285
# Epoch 22/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6945 - accuracy: 0.5235
# Epoch 22: val_accuracy did not improve from 0.54750
# 2000/2000 [==============================] - 174s 87ms/step - loss: 0.6945 - accuracy: 0.5235 - val_loss: 0.6934 - val_accuracy: 0.5205
# Epoch 23/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.5242
# Epoch 23: val_accuracy did not improve from 0.54750
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6940 - accuracy: 0.5242 - val_loss: 0.7131 - val_accuracy: 0.5405
# Epoch 24/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5289
# Epoch 24: val_accuracy improved from 0.54750 to 0.55750, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 179s 89ms/step - loss: 0.6929 - accuracy: 0.5289 - val_loss: 0.6818 - val_accuracy: 0.5575
# Epoch 25/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.5213
# Epoch 25: val_accuracy did not improve from 0.55750
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6939 - accuracy: 0.5213 - val_loss: 0.6859 - val_accuracy: 0.5000
# Epoch 26/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5263
# Epoch 26: val_accuracy did not improve from 0.55750
# 2000/2000 [==============================] - 174s 87ms/step - loss: 0.6927 - accuracy: 0.5263 - val_loss: 0.6859 - val_accuracy: 0.5000
# Epoch 27/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5256
# Epoch 27: val_accuracy improved from 0.55750 to 0.56300, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 174s 87ms/step - loss: 0.6930 - accuracy: 0.5256 - val_loss: 0.6854 - val_accuracy: 0.5630
# Epoch 28/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6922 - accuracy: 0.5284
# Epoch 28: val_accuracy did not improve from 0.56300
# 2000/2000 [==============================] - 174s 87ms/step - loss: 0.6922 - accuracy: 0.5284 - val_loss: 0.6910 - val_accuracy: 0.5370
# Epoch 29/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6915 - accuracy: 0.5255
# Epoch 29: val_accuracy improved from 0.56300 to 0.56600, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 174s 87ms/step - loss: 0.6915 - accuracy: 0.5255 - val_loss: 0.6808 - val_accuracy: 0.5660
# Epoch 30/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.5232
# Epoch 30: val_accuracy improved from 0.56600 to 0.56750, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 174s 87ms/step - loss: 0.6938 - accuracy: 0.5232 - val_loss: 0.6642 - val_accuracy: 0.5675
# Epoch 31/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6907 - accuracy: 0.5395
# Epoch 31: val_accuracy improved from 0.56750 to 0.57250, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 179s 90ms/step - loss: 0.6907 - accuracy: 0.5395 - val_loss: 0.6762 - val_accuracy: 0.5725
# Epoch 32/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.5390
# Epoch 32: val_accuracy did not improve from 0.57250
# 2000/2000 [==============================] - 179s 90ms/step - loss: 0.6902 - accuracy: 0.5390 - val_loss: 0.6764 - val_accuracy: 0.5700
# Epoch 33/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6871 - accuracy: 0.5409
# Epoch 33: val_accuracy did not improve from 0.57250
# 2000/2000 [==============================] - 179s 89ms/step - loss: 0.6871 - accuracy: 0.5409 - val_loss: 0.7695 - val_accuracy: 0.5040
# Epoch 34/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.5400
# Epoch 34: val_accuracy did not improve from 0.57250
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6902 - accuracy: 0.5400 - val_loss: 0.7466 - val_accuracy: 0.5230
# Epoch 35/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6896 - accuracy: 0.5374
# Epoch 35: val_accuracy improved from 0.57250 to 0.59650, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6896 - accuracy: 0.5374 - val_loss: 0.6728 - val_accuracy: 0.5965
# Epoch 36/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6874 - accuracy: 0.5409
# Epoch 36: val_accuracy did not improve from 0.59650
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6874 - accuracy: 0.5409 - val_loss: 0.6721 - val_accuracy: 0.5605
# Epoch 37/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6894 - accuracy: 0.5439
# Epoch 37: val_accuracy did not improve from 0.59650
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6894 - accuracy: 0.5439 - val_loss: 0.6772 - val_accuracy: 0.5750
# Epoch 38/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6857 - accuracy: 0.5508
# Epoch 38: val_accuracy did not improve from 0.59650
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6857 - accuracy: 0.5508 - val_loss: 0.7130 - val_accuracy: 0.5560
# Epoch 39/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6850 - accuracy: 0.5526
# Epoch 39: val_accuracy did not improve from 0.59650
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6850 - accuracy: 0.5526 - val_loss: 0.6761 - val_accuracy: 0.5855
# Epoch 40/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6854 - accuracy: 0.5435
# Epoch 40: val_accuracy did not improve from 0.59650
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6854 - accuracy: 0.5435 - val_loss: 0.6923 - val_accuracy: 0.5880
# Epoch 41/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6821 - accuracy: 0.5556
# Epoch 41: val_accuracy did not improve from 0.59650
# 2000/2000 [==============================] - 180s 90ms/step - loss: 0.6821 - accuracy: 0.5556 - val_loss: 0.6842 - val_accuracy: 0.5615
# Epoch 42/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6832 - accuracy: 0.5541
# Epoch 42: val_accuracy did not improve from 0.59650
# 2000/2000 [==============================] - 181s 90ms/step - loss: 0.6832 - accuracy: 0.5541 - val_loss: 0.6989 - val_accuracy: 0.5550
# Epoch 43/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6822 - accuracy: 0.5642
# Epoch 43: val_accuracy did not improve from 0.59650
# 2000/2000 [==============================] - 173s 87ms/step - loss: 0.6822 - accuracy: 0.5642 - val_loss: 0.6832 - val_accuracy: 0.5585
# Epoch 44/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6812 - accuracy: 0.5579
# Epoch 44: val_accuracy improved from 0.59650 to 0.59700, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 174s 87ms/step - loss: 0.6812 - accuracy: 0.5579 - val_loss: 0.6547 - val_accuracy: 0.5970
# Epoch 45/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6766 - accuracy: 0.5615
# Epoch 45: val_accuracy did not improve from 0.59700
# 2000/2000 [==============================] - 174s 87ms/step - loss: 0.6766 - accuracy: 0.5615 - val_loss: 0.6960 - val_accuracy: 0.5310
# Epoch 46/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6733 - accuracy: 0.5683
# Epoch 46: val_accuracy did not improve from 0.59700
# 2000/2000 [==============================] - 174s 87ms/step - loss: 0.6733 - accuracy: 0.5683 - val_loss: 0.6905 - val_accuracy: 0.5485
# Epoch 47/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6780 - accuracy: 0.5599
# Epoch 47: val_accuracy improved from 0.59700 to 0.62700, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 174s 87ms/step - loss: 0.6780 - accuracy: 0.5599 - val_loss: 0.6343 - val_accuracy: 0.6270
# Epoch 48/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6752 - accuracy: 0.5665
# Epoch 48: val_accuracy did not improve from 0.62700
# 2000/2000 [==============================] - 177s 88ms/step - loss: 0.6752 - accuracy: 0.5665 - val_loss: 0.6397 - val_accuracy: 0.5845
# Epoch 49/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6741 - accuracy: 0.5650
# Epoch 49: val_accuracy did not improve from 0.62700
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6741 - accuracy: 0.5650 - val_loss: 0.6717 - val_accuracy: 0.6035
# Epoch 50/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6715 - accuracy: 0.5673
# Epoch 50: val_accuracy did not improve from 0.62700
# 2000/2000 [==============================] - 177s 88ms/step - loss: 0.6715 - accuracy: 0.5673 - val_loss: 0.6360 - val_accuracy: 0.6095
# Epoch 51/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6642 - accuracy: 0.5850
# Epoch 51: val_accuracy did not improve from 0.62700
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6642 - accuracy: 0.5850 - val_loss: 0.6526 - val_accuracy: 0.5665
# Epoch 52/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6625 - accuracy: 0.5838
# Epoch 52: val_accuracy did not improve from 0.62700
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6625 - accuracy: 0.5838 - val_loss: 0.6352 - val_accuracy: 0.6125
# Epoch 53/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6645 - accuracy: 0.5820
# Epoch 53: val_accuracy improved from 0.62700 to 0.63050, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6645 - accuracy: 0.5820 - val_loss: 0.6481 - val_accuracy: 0.6305
# Epoch 54/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6600 - accuracy: 0.5826
# Epoch 54: val_accuracy did not improve from 0.63050
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6600 - accuracy: 0.5826 - val_loss: 0.9634 - val_accuracy: 0.5635
# Epoch 55/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6620 - accuracy: 0.5847
# Epoch 55: val_accuracy did not improve from 0.63050
# 2000/2000 [==============================] - 177s 88ms/step - loss: 0.6620 - accuracy: 0.5847 - val_loss: 0.7075 - val_accuracy: 0.6240
# Epoch 56/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6541 - accuracy: 0.5914
# Epoch 56: val_accuracy did not improve from 0.63050
# 2000/2000 [==============================] - 177s 88ms/step - loss: 0.6541 - accuracy: 0.5914 - val_loss: 0.6399 - val_accuracy: 0.6025
# Epoch 57/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6516 - accuracy: 0.6018
# Epoch 57: val_accuracy did not improve from 0.63050
# 2000/2000 [==============================] - 177s 88ms/step - loss: 0.6516 - accuracy: 0.6018 - val_loss: 0.6510 - val_accuracy: 0.6130
# Epoch 58/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6524 - accuracy: 0.5844
# Epoch 58: val_accuracy did not improve from 0.63050
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6524 - accuracy: 0.5844 - val_loss: 0.6109 - val_accuracy: 0.6135
# Epoch 59/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6492 - accuracy: 0.6050
# Epoch 59: val_accuracy improved from 0.63050 to 0.65200, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 173s 87ms/step - loss: 0.6492 - accuracy: 0.6050 - val_loss: 0.6016 - val_accuracy: 0.6520
# Epoch 60/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6478 - accuracy: 0.6089
# Epoch 60: val_accuracy did not improve from 0.65200
# 2000/2000 [==============================] - 173s 87ms/step - loss: 0.6478 - accuracy: 0.6089 - val_loss: 0.6502 - val_accuracy: 0.5920
# Epoch 61/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6467 - accuracy: 0.5981
# Epoch 61: val_accuracy did not improve from 0.65200
# 2000/2000 [==============================] - 173s 87ms/step - loss: 0.6467 - accuracy: 0.5981 - val_loss: 0.6446 - val_accuracy: 0.5870
# Epoch 62/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6439 - accuracy: 0.5978
# Epoch 62: val_accuracy did not improve from 0.65200
# 2000/2000 [==============================] - 173s 87ms/step - loss: 0.6439 - accuracy: 0.5978 - val_loss: 0.6338 - val_accuracy: 0.6445
# Epoch 63/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6433 - accuracy: 0.6111
# Epoch 63: val_accuracy did not improve from 0.65200
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6433 - accuracy: 0.6111 - val_loss: 0.6125 - val_accuracy: 0.6250
# Epoch 64/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6441 - accuracy: 0.6144
# Epoch 64: val_accuracy did not improve from 0.65200
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6441 - accuracy: 0.6144 - val_loss: 0.6104 - val_accuracy: 0.6455
# Epoch 65/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6408 - accuracy: 0.6149
# Epoch 65: val_accuracy did not improve from 0.65200
# 2000/2000 [==============================] - 177s 88ms/step - loss: 0.6408 - accuracy: 0.6149 - val_loss: 0.6370 - val_accuracy: 0.6510
# Epoch 66/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6352 - accuracy: 0.6183
# Epoch 66: val_accuracy improved from 0.65200 to 0.65700, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 177s 88ms/step - loss: 0.6352 - accuracy: 0.6183 - val_loss: 0.5827 - val_accuracy: 0.6570
# Epoch 67/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6349 - accuracy: 0.6159
# Epoch 67: val_accuracy did not improve from 0.65700
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6349 - accuracy: 0.6159 - val_loss: 0.6064 - val_accuracy: 0.6560
# Epoch 68/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6329 - accuracy: 0.6181
# Epoch 68: val_accuracy did not improve from 0.65700
# 2000/2000 [==============================] - 172s 86ms/step - loss: 0.6329 - accuracy: 0.6181 - val_loss: 0.7392 - val_accuracy: 0.6305
# Epoch 69/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6353 - accuracy: 0.6189
# Epoch 69: val_accuracy did not improve from 0.65700
# 2000/2000 [==============================] - 172s 86ms/step - loss: 0.6353 - accuracy: 0.6189 - val_loss: 0.5965 - val_accuracy: 0.6540
# Epoch 70/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6307 - accuracy: 0.6171
# Epoch 70: val_accuracy did not improve from 0.65700
# 2000/2000 [==============================] - 172s 86ms/step - loss: 0.6307 - accuracy: 0.6171 - val_loss: 0.7776 - val_accuracy: 0.6050
# Epoch 71/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6343 - accuracy: 0.6192
# Epoch 71: val_accuracy did not improve from 0.65700
# 2000/2000 [==============================] - 172s 86ms/step - loss: 0.6343 - accuracy: 0.6192 - val_loss: 0.7492 - val_accuracy: 0.5350
# Epoch 72/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6302 - accuracy: 0.6254
# Epoch 72: val_accuracy did not improve from 0.65700
# 2000/2000 [==============================] - 173s 87ms/step - loss: 0.6302 - accuracy: 0.6254 - val_loss: 0.6344 - val_accuracy: 0.6510
# Epoch 73/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6280 - accuracy: 0.6288
# Epoch 73: val_accuracy did not improve from 0.65700
# 2000/2000 [==============================] - 177s 88ms/step - loss: 0.6280 - accuracy: 0.6288 - val_loss: 0.6129 - val_accuracy: 0.6325
# Epoch 74/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6292 - accuracy: 0.6254
# Epoch 74: val_accuracy improved from 0.65700 to 0.66350, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6292 - accuracy: 0.6254 - val_loss: 0.6025 - val_accuracy: 0.6635
# Epoch 75/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6223 - accuracy: 0.6309
# Epoch 75: val_accuracy did not improve from 0.66350
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6223 - accuracy: 0.6309 - val_loss: 1.9652 - val_accuracy: 0.5410
# Epoch 76/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6284 - accuracy: 0.6224
# Epoch 76: val_accuracy did not improve from 0.66350
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6284 - accuracy: 0.6224 - val_loss: 0.6505 - val_accuracy: 0.6485
# Epoch 77/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6191 - accuracy: 0.6214
# Epoch 77: val_accuracy did not improve from 0.66350
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6191 - accuracy: 0.6214 - val_loss: 0.6455 - val_accuracy: 0.6375
# Epoch 78/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6201 - accuracy: 0.6289
# Epoch 78: val_accuracy did not improve from 0.66350
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6201 - accuracy: 0.6289 - val_loss: 0.6626 - val_accuracy: 0.6555
# Epoch 79/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6242 - accuracy: 0.6261
# Epoch 79: val_accuracy improved from 0.66350 to 0.67800, saving model to D:/testing_1/Model_kan_strategy_04S-UNIWARD_1728855643.6558657\saved-model.hdf5
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6242 - accuracy: 0.6261 - val_loss: 0.5643 - val_accuracy: 0.6780
# Epoch 80/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6253 - accuracy: 0.6161
# Epoch 80: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6253 - accuracy: 0.6161 - val_loss: 0.6036 - val_accuracy: 0.6685
# Epoch 81/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6188 - accuracy: 0.6308
# Epoch 81: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6188 - accuracy: 0.6308 - val_loss: 0.5903 - val_accuracy: 0.6550
# Epoch 82/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6198 - accuracy: 0.6292
# Epoch 82: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6198 - accuracy: 0.6292 - val_loss: 0.5882 - val_accuracy: 0.6765
# Epoch 83/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6182 - accuracy: 0.6369
# Epoch 83: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6182 - accuracy: 0.6369 - val_loss: 0.7236 - val_accuracy: 0.6325
# Epoch 84/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6184 - accuracy: 0.6295
# Epoch 84: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6184 - accuracy: 0.6295 - val_loss: 0.6516 - val_accuracy: 0.6430
# Epoch 85/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6135 - accuracy: 0.6300
# Epoch 85: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6135 - accuracy: 0.6300 - val_loss: 0.8397 - val_accuracy: 0.5560
# Epoch 86/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6229 - accuracy: 0.6215
# Epoch 86: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6229 - accuracy: 0.6215 - val_loss: 0.6242 - val_accuracy: 0.6050
# Epoch 87/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6218 - accuracy: 0.6289
# Epoch 87: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6218 - accuracy: 0.6289 - val_loss: 0.6330 - val_accuracy: 0.6470
# Epoch 88/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6199 - accuracy: 0.6288
# Epoch 88: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6199 - accuracy: 0.6288 - val_loss: 0.6863 - val_accuracy: 0.6155
# Epoch 89/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6152 - accuracy: 0.6324
# Epoch 89: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6152 - accuracy: 0.6324 - val_loss: 0.6092 - val_accuracy: 0.6405
# Epoch 90/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6147 - accuracy: 0.6385
# Epoch 90: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6147 - accuracy: 0.6385 - val_loss: 0.6133 - val_accuracy: 0.6660
# Epoch 91/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6169 - accuracy: 0.6366
# Epoch 91: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 88ms/step - loss: 0.6169 - accuracy: 0.6366 - val_loss: 0.6095 - val_accuracy: 0.6540
# Epoch 92/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6191 - accuracy: 0.6342
# Epoch 92: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6191 - accuracy: 0.6342 - val_loss: 0.6425 - val_accuracy: 0.6515
# Epoch 93/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6150 - accuracy: 0.6290
# Epoch 93: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6150 - accuracy: 0.6290 - val_loss: 0.5759 - val_accuracy: 0.6570
# Epoch 94/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6088 - accuracy: 0.6395
# Epoch 94: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 88ms/step - loss: 0.6088 - accuracy: 0.6395 - val_loss: 0.7483 - val_accuracy: 0.6435
# Epoch 95/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6136 - accuracy: 0.6396
# Epoch 95: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6136 - accuracy: 0.6396 - val_loss: 0.6382 - val_accuracy: 0.6380
# Epoch 96/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6139 - accuracy: 0.6432
# Epoch 96: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6139 - accuracy: 0.6432 - val_loss: 0.7426 - val_accuracy: 0.6255
# Epoch 97/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6169 - accuracy: 0.6327
# Epoch 97: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 175s 88ms/step - loss: 0.6169 - accuracy: 0.6327 - val_loss: 0.6983 - val_accuracy: 0.6195
# Epoch 98/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6149 - accuracy: 0.6406
# Epoch 98: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6149 - accuracy: 0.6406 - val_loss: 0.6412 - val_accuracy: 0.6445
# Epoch 99/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6131 - accuracy: 0.6374
# Epoch 99: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6131 - accuracy: 0.6374 - val_loss: 0.7064 - val_accuracy: 0.5830
# Epoch 100/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6128 - accuracy: 0.6388
# Epoch 100: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6128 - accuracy: 0.6388 - val_loss: 0.6059 - val_accuracy: 0.6595
# Epoch 101/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6127 - accuracy: 0.6332
# Epoch 101: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6127 - accuracy: 0.6332 - val_loss: 0.6723 - val_accuracy: 0.6285
# Epoch 102/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6111 - accuracy: 0.6364
# Epoch 102: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6111 - accuracy: 0.6364 - val_loss: 0.6788 - val_accuracy: 0.6575
# Epoch 103/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6076 - accuracy: 0.6401
# Epoch 103: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 88ms/step - loss: 0.6076 - accuracy: 0.6401 - val_loss: 0.6032 - val_accuracy: 0.6180
# Epoch 104/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6129 - accuracy: 0.6394
# Epoch 104: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 179s 90ms/step - loss: 0.6129 - accuracy: 0.6394 - val_loss: 0.5897 - val_accuracy: 0.6480
# Epoch 105/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6107 - accuracy: 0.6359
# Epoch 105: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 180s 90ms/step - loss: 0.6107 - accuracy: 0.6359 - val_loss: 0.6738 - val_accuracy: 0.6215
# Epoch 106/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6142 - accuracy: 0.6270
# Epoch 106: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 179s 89ms/step - loss: 0.6142 - accuracy: 0.6270 - val_loss: 0.6417 - val_accuracy: 0.6570
# Epoch 107/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6164 - accuracy: 0.6299
# Epoch 107: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6164 - accuracy: 0.6299 - val_loss: 0.6190 - val_accuracy: 0.6080
# Epoch 108/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6055 - accuracy: 0.6404
# Epoch 108: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6055 - accuracy: 0.6404 - val_loss: 0.9082 - val_accuracy: 0.5900
# Epoch 109/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6059 - accuracy: 0.6388
# Epoch 109: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6059 - accuracy: 0.6388 - val_loss: 0.6862 - val_accuracy: 0.5610
# Epoch 110/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6035 - accuracy: 0.6444
# Epoch 110: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6035 - accuracy: 0.6444 - val_loss: 0.6094 - val_accuracy: 0.6455
# Epoch 111/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6104 - accuracy: 0.6329
# Epoch 111: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 182s 91ms/step - loss: 0.6104 - accuracy: 0.6329 - val_loss: 0.6132 - val_accuracy: 0.6495
# Epoch 112/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6094 - accuracy: 0.6431
# Epoch 112: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 175s 87ms/step - loss: 0.6094 - accuracy: 0.6431 - val_loss: 0.6743 - val_accuracy: 0.6445
# Epoch 113/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6088 - accuracy: 0.6424
# Epoch 113: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 174s 87ms/step - loss: 0.6088 - accuracy: 0.6424 - val_loss: 0.5867 - val_accuracy: 0.6710
# Epoch 114/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6091 - accuracy: 0.6444
# Epoch 114: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 173s 87ms/step - loss: 0.6091 - accuracy: 0.6444 - val_loss: 0.5898 - val_accuracy: 0.6730
# Epoch 115/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6076 - accuracy: 0.6325
# Epoch 115: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 174s 87ms/step - loss: 0.6076 - accuracy: 0.6325 - val_loss: 0.6403 - val_accuracy: 0.6470
# Epoch 116/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6051 - accuracy: 0.6430
# Epoch 116: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 174s 87ms/step - loss: 0.6051 - accuracy: 0.6430 - val_loss: 0.7168 - val_accuracy: 0.5650
# Epoch 117/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6052 - accuracy: 0.6385
# Epoch 117: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 88ms/step - loss: 0.6052 - accuracy: 0.6385 - val_loss: 0.6233 - val_accuracy: 0.6515
# Epoch 118/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6101 - accuracy: 0.6417
# Epoch 118: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6101 - accuracy: 0.6417 - val_loss: 0.6968 - val_accuracy: 0.5770
# Epoch 119/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6083 - accuracy: 0.6395
# Epoch 119: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6083 - accuracy: 0.6395 - val_loss: 0.8346 - val_accuracy: 0.6235
# Epoch 120/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6060 - accuracy: 0.6464
# Epoch 120: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6060 - accuracy: 0.6464 - val_loss: 0.6211 - val_accuracy: 0.6070
# Epoch 121/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6023 - accuracy: 0.6484
# Epoch 121: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.6023 - accuracy: 0.6484 - val_loss: 0.8186 - val_accuracy: 0.6140
# Epoch 122/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6070 - accuracy: 0.6434
# Epoch 122: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6070 - accuracy: 0.6434 - val_loss: 1.0677 - val_accuracy: 0.5910
# Epoch 123/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6061 - accuracy: 0.6476
# Epoch 123: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 180s 90ms/step - loss: 0.6061 - accuracy: 0.6476 - val_loss: 0.6028 - val_accuracy: 0.6590
# Epoch 124/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5996 - accuracy: 0.6466
# Epoch 124: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 183s 91ms/step - loss: 0.5996 - accuracy: 0.6466 - val_loss: 0.6622 - val_accuracy: 0.6540
# Epoch 125/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6021 - accuracy: 0.6510
# Epoch 125: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 181s 90ms/step - loss: 0.6021 - accuracy: 0.6510 - val_loss: 0.6521 - val_accuracy: 0.6420
# Epoch 126/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6001 - accuracy: 0.6484
# Epoch 126: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 181s 91ms/step - loss: 0.6001 - accuracy: 0.6484 - val_loss: 1.0060 - val_accuracy: 0.6135
# Epoch 127/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6056 - accuracy: 0.6499
# Epoch 127: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 181s 91ms/step - loss: 0.6056 - accuracy: 0.6499 - val_loss: 0.6484 - val_accuracy: 0.6145
# Epoch 128/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6059 - accuracy: 0.6478
# Epoch 128: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 181s 91ms/step - loss: 0.6059 - accuracy: 0.6478 - val_loss: 1.0044 - val_accuracy: 0.5775
# Epoch 129/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5973 - accuracy: 0.6432
# Epoch 129: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 180s 90ms/step - loss: 0.5973 - accuracy: 0.6432 - val_loss: 0.7103 - val_accuracy: 0.6440
# Epoch 130/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6019 - accuracy: 0.6395
# Epoch 130: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 171s 85ms/step - loss: 0.6019 - accuracy: 0.6395 - val_loss: 0.6948 - val_accuracy: 0.5965
# Epoch 131/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5984 - accuracy: 0.6488
# Epoch 131: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 170s 85ms/step - loss: 0.5984 - accuracy: 0.6488 - val_loss: 0.6204 - val_accuracy: 0.6515
# Epoch 132/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6051 - accuracy: 0.6345
# Epoch 132: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 170s 85ms/step - loss: 0.6051 - accuracy: 0.6345 - val_loss: 0.7294 - val_accuracy: 0.6515
# Epoch 133/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6058 - accuracy: 0.6510
# Epoch 133: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6058 - accuracy: 0.6510 - val_loss: 0.7938 - val_accuracy: 0.6295
# Epoch 134/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6040 - accuracy: 0.6398
# Epoch 134: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 175s 87ms/step - loss: 0.6040 - accuracy: 0.6398 - val_loss: 0.5875 - val_accuracy: 0.6660
# Epoch 135/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5991 - accuracy: 0.6491
# Epoch 135: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 174s 87ms/step - loss: 0.5991 - accuracy: 0.6491 - val_loss: 1.1692 - val_accuracy: 0.6060
# Epoch 136/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6016 - accuracy: 0.6447
# Epoch 136: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 172s 86ms/step - loss: 0.6016 - accuracy: 0.6447 - val_loss: 0.9892 - val_accuracy: 0.5810
# Epoch 137/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5941 - accuracy: 0.6551
# Epoch 137: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 172s 86ms/step - loss: 0.5941 - accuracy: 0.6551 - val_loss: 0.8590 - val_accuracy: 0.6395
# Epoch 138/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6033 - accuracy: 0.6451
# Epoch 138: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 172s 86ms/step - loss: 0.6033 - accuracy: 0.6451 - val_loss: 0.8320 - val_accuracy: 0.6465
# Epoch 139/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5984 - accuracy: 0.6499
# Epoch 139: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 173s 87ms/step - loss: 0.5984 - accuracy: 0.6499 - val_loss: 0.7064 - val_accuracy: 0.6430
# Epoch 140/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6023 - accuracy: 0.6435
# Epoch 140: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 176s 88ms/step - loss: 0.6023 - accuracy: 0.6435 - val_loss: 0.6474 - val_accuracy: 0.6095
# Epoch 141/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6000 - accuracy: 0.6460
# Epoch 141: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6000 - accuracy: 0.6460 - val_loss: 0.6869 - val_accuracy: 0.6720
# Epoch 142/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5999 - accuracy: 0.6528
# Epoch 142: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5999 - accuracy: 0.6528 - val_loss: 0.6678 - val_accuracy: 0.6345
# Epoch 143/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6037 - accuracy: 0.6491
# Epoch 143: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6037 - accuracy: 0.6491 - val_loss: 0.8107 - val_accuracy: 0.6340
# Epoch 144/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5989 - accuracy: 0.6491
# Epoch 144: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 179s 89ms/step - loss: 0.5989 - accuracy: 0.6491 - val_loss: 0.9548 - val_accuracy: 0.6255
# Epoch 145/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5991 - accuracy: 0.6465
# Epoch 145: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 179s 90ms/step - loss: 0.5991 - accuracy: 0.6465 - val_loss: 0.6039 - val_accuracy: 0.6475
# Epoch 146/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6003 - accuracy: 0.6461
# Epoch 146: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 180s 90ms/step - loss: 0.6003 - accuracy: 0.6461 - val_loss: 0.8721 - val_accuracy: 0.6545
# Epoch 147/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5984 - accuracy: 0.6447
# Epoch 147: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 179s 89ms/step - loss: 0.5984 - accuracy: 0.6447 - val_loss: 0.7578 - val_accuracy: 0.6270
# Epoch 148/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6001 - accuracy: 0.6530
# Epoch 148: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6001 - accuracy: 0.6530 - val_loss: 0.8457 - val_accuracy: 0.6185
# Epoch 149/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5939 - accuracy: 0.6504
# Epoch 149: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5939 - accuracy: 0.6504 - val_loss: 0.7294 - val_accuracy: 0.6210
# Epoch 150/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6005 - accuracy: 0.6531
# Epoch 150: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6005 - accuracy: 0.6531 - val_loss: 0.6527 - val_accuracy: 0.6205
# Epoch 151/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5970 - accuracy: 0.6589
# Epoch 151: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5970 - accuracy: 0.6589 - val_loss: 1.0267 - val_accuracy: 0.6245
# Epoch 152/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6032 - accuracy: 0.6489
# Epoch 152: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6032 - accuracy: 0.6489 - val_loss: 0.8283 - val_accuracy: 0.5745
# Epoch 153/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6025 - accuracy: 0.6471
# Epoch 153: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6025 - accuracy: 0.6471 - val_loss: 0.9516 - val_accuracy: 0.6015
# Epoch 154/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6040 - accuracy: 0.6510
# Epoch 154: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6040 - accuracy: 0.6510 - val_loss: 1.1248 - val_accuracy: 0.6040
# Epoch 155/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6045 - accuracy: 0.6490
# Epoch 155: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6045 - accuracy: 0.6490 - val_loss: 2.3658 - val_accuracy: 0.5570
# Epoch 156/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5967 - accuracy: 0.6470
# Epoch 156: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5967 - accuracy: 0.6470 - val_loss: 0.7994 - val_accuracy: 0.6330
# Epoch 157/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5978 - accuracy: 0.6531
# Epoch 157: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.5978 - accuracy: 0.6531 - val_loss: 0.6661 - val_accuracy: 0.6575
# Epoch 158/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5929 - accuracy: 0.6547
# Epoch 158: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5929 - accuracy: 0.6547 - val_loss: 0.6537 - val_accuracy: 0.5690
# Epoch 159/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5997 - accuracy: 0.6518
# Epoch 159: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5997 - accuracy: 0.6518 - val_loss: 0.7584 - val_accuracy: 0.6245
# Epoch 160/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5954 - accuracy: 0.6549
# Epoch 160: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5954 - accuracy: 0.6549 - val_loss: 2.2170 - val_accuracy: 0.5585
# Epoch 161/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5965 - accuracy: 0.6551
# Epoch 161: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.5965 - accuracy: 0.6551 - val_loss: 0.8681 - val_accuracy: 0.6110
# Epoch 162/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5945 - accuracy: 0.6543
# Epoch 162: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5945 - accuracy: 0.6543 - val_loss: 1.2453 - val_accuracy: 0.5995
# Epoch 163/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5994 - accuracy: 0.6525
# Epoch 163: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.5994 - accuracy: 0.6525 - val_loss: 0.7803 - val_accuracy: 0.5625
# Epoch 164/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5997 - accuracy: 0.6599
# Epoch 164: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5997 - accuracy: 0.6599 - val_loss: 0.7339 - val_accuracy: 0.5755
# Epoch 165/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5986 - accuracy: 0.6556
# Epoch 165: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5986 - accuracy: 0.6556 - val_loss: 1.0866 - val_accuracy: 0.5410
# Epoch 166/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5972 - accuracy: 0.6526
# Epoch 166: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5972 - accuracy: 0.6526 - val_loss: 1.0926 - val_accuracy: 0.6135
# Epoch 167/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5975 - accuracy: 0.6528
# Epoch 167: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5975 - accuracy: 0.6528 - val_loss: 0.6149 - val_accuracy: 0.6585
# Epoch 168/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5974 - accuracy: 0.6565
# Epoch 168: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5974 - accuracy: 0.6565 - val_loss: 0.7119 - val_accuracy: 0.6610
# Epoch 169/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5975 - accuracy: 0.6531
# Epoch 169: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 177s 89ms/step - loss: 0.5975 - accuracy: 0.6531 - val_loss: 0.7446 - val_accuracy: 0.6395
# Epoch 170/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5985 - accuracy: 0.6506
# Epoch 170: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5985 - accuracy: 0.6506 - val_loss: 0.7061 - val_accuracy: 0.6370
# Epoch 171/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5963 - accuracy: 0.6522
# Epoch 171: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5963 - accuracy: 0.6522 - val_loss: 1.3108 - val_accuracy: 0.5975
# Epoch 172/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6016 - accuracy: 0.6480
# Epoch 172: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.6016 - accuracy: 0.6480 - val_loss: 0.7946 - val_accuracy: 0.5850
# Epoch 173/200
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5970 - accuracy: 0.6545
# Epoch 173: val_accuracy did not improve from 0.67800
# 2000/2000 [==============================] - 178s 89ms/step - loss: 0.5970 - accuracy: 0.6545 - val_loss: 0.8277 - val_accuracy: 0.6070
# Epoch 174/200
# 1590/2000 [======================>.......] - ETA: 33s - loss: 0.5999 - accuracy: 0.6469

# %% [markdown]
# ## Test

# %%
model= Xu_Net_strategy() 
PATH_trained_models = "D:\modelos\Model_XU_Net_04S-UNIWARD_1728342103.1582682\saved-model.hdf5"
Final_Results_Test(model,PATH_trained_models)
# Out:
# using 2 classes
# Xunet
#
#
# Best
# D:\modelos\Model_XU_Net_04S-UNIWARD_1728342103.1582682\saved-model.hdf5
# Loss=0.7837 y Accuracy=0.7031
