# %% [markdown]
# # Xu-Net

# %% [markdown]
# ## Libraries

# %%
import numpy
import numpy as np
import random
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from keras.layers import Activation
import tensorflow as tf
import cv2
from tensorflow.keras.layers import Lambda, Layer, ReLU
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, LSTM, SpatialDropout2D, Concatenate
tf.keras.layers.Concatenate()
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, UpSampling2D, BatchNormalization
from keras.layers.core import Reshape
from keras import optimizers
from tensorflow.keras import regularizers
from keras import Input, Model
from time import time
import time as tm
from keras.initializers import Constant, RandomNormal, glorot_normal
from tensorflow.keras.models import load_model
from tensorflow.keras.regularizers import l2
from keras import backend as K
from tensorflow.keras.utils import plot_model
from keras.layers import  concatenate

from tfkan.layers import DenseKAN
from tfkan.layers import Conv2DKAN
from tfkan.layers import base

# %% [markdown]
# ## 30 SRM filters for preprocessing and the activation function

# %%
################################################## 30 SRM FILTERS
srm_weights = np.load('SRM_Kernels.npy') 
biasSRM=numpy.ones(30)
print (srm_weights.shape)
################################################## TLU ACTIVATION FUNCTION
T3 = 3;
def Tanh3(x):
    tanh3 = K.tanh(x)*T3
    return tanh3
##################################################
# Out:
# (5, 5, 1, 30)

# %% [markdown]
# ## Functions

# %%
## DCT filters function

def make_DCT_filter():
    with tf.name_scope("DCT"):
        # Initialize DCT filters
        DCT_filter_n = np.zeros([5, 5, 1, 64])
        # Definition of 8x8 mesh grid
        XX, YY = np.meshgrid(range(5), range(5))
        # DCT basis as filters
        C=np.ones(5)
        C[0]=1/np.sqrt(2)
        for v in range(5):
            for u in range(5):
                DCT_filter_n[:, :, 0, u+v*5]=(2*C[v]*C[u]/5)*np.cos((2*YY+1)*v*np.pi/(10))*np.cos((2*XX+1)*u*np.pi/(10))

        DCT_filter=tf.constant(DCT_filter_n.astype(np.float32))

        return DCT_filter

def Fun(x):
    fun = tf.keras.activations.hard_sigmoid(x)*3
    return fun

def squeeze_excitation_layer(input_layer, out_dim, ratio, conv):
  squeeze = tf.keras.layers.GlobalAveragePooling2D()(input_layer)
  excitation = tf.keras.layers.Dense(units=out_dim / ratio, activation='relu')(squeeze)
  excitation = tf.keras.layers.Dense(out_dim,activation='sigmoid')(excitation)
  excitation = tf.reshape(excitation, [-1,1,1,out_dim])
  scale = tf.keras.layers.multiply([input_layer, excitation])
  
  if conv:
    shortcut = tf.keras.layers.Conv2D(out_dim,kernel_size=1,strides=1,
                                      padding='same',kernel_initializer='he_normal')(input_layer)
    shortcut = tf.keras.layers.BatchNormalization()(shortcut)
  else:
    shortcut = input_layer
  out = tf.keras.layers.add([shortcut, scale])
  return out

# %% [markdown]
# ## Xu-Net architecture

# %%
def Xu_Net_strategy():
    
    img_size=256
    
    DCT_filter = make_DCT_filter()
    print(DCT_filter.shape)

    filters = np.concatenate([DCT_filter,srm_weights],axis=3)
    filters.shape
    
    bias = np.ones(94)

    tf.keras.backend.clear_session()
    inputs = tf.keras.Input(shape=(img_size,img_size,1), name="input")
    # Layer 1
    #conv0 =   tf.keras.layers.Conv2D(94, (5,5), weights=[filters,bias], strides=(1,1), trainable=False, activation=Tanh3, use_bias=True)(inputs)

    #Block 1
    layers_ty = tf.keras.layers.Conv2D(94, (5,5), weights=[filters,bias], strides=(1,1), trainable=False, padding='same', activation=Tanh3, use_bias=True)(inputs)
    layers_tn = tf.keras.layers.Conv2D(94, (5,5), weights=[filters,bias], strides=(1,1), trainable=True, padding='same', activation=Tanh3, use_bias=True)(inputs)
    layers1 = tf.keras.layers.add([layers_ty, layers_tn])

    
    layers = tf.keras.layers.Conv2D(94, (1,1), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers1) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
  
    layers = tf.keras.layers.Conv2D(94, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)

    layers = tf.keras.layers.Conv2D(94, (1,1), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    block_squeeze = squeeze_excitation_layer(layers, out_dim=94, ratio=32.0, conv=False)

    layers_Tr_1 = tf.keras.layers.add([layers1, block_squeeze])

    layers = tf.keras.layers.Conv2D(94, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers_Tr_1) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)

    layers = tf.keras.layers.Conv2D(94, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers3 = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)


    layers_Tr_2 = tf.keras.layers.add([layers_Tr_1, layers3])

    layers = tf.keras.layers.Conv2D(30, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers_Tr_2) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers_n = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)

    layers = tf.keras.layers.Conv2D(30, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers_n) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers4 = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)

    
    
    
    
    #Block 1
    
    #Layer 0
    layers = Conv2D(8, (5,5), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers4) 
    layers = ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = Lambda(tf.keras.backend.abs)(layers)
    layers = BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = Concatenate()([layers, layers, layers])
    
    #Block 2
    
    #Layer 1
    layers = tf.keras.layers.SpatialDropout2D(rate=0.1)(layers)
    layers = Conv2D(16, (5,5), strides=1,padding="same", kernel_initializer='glorot_normal',kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)  
    layers = AveragePooling2D((5,5), strides= 2, padding='same')(layers)
    
    #Block 3
    
    #Layer 2
    layers = tf.keras.layers.SpatialDropout2D(rate=0.1)(layers)
    layers = Conv2D(32, (1,1), strides=1,padding="same", kernel_initializer='glorot_normal',kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=False, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = AveragePooling2D((5,5), strides= 2,padding="same")(layers)
    
    #Block 4
    #Layer 3
    layers = tf.keras.layers.SpatialDropout2D(rate=0.1)(layers)
    layers = Conv2D(64, (1,1), strides=1,padding="same", kernel_initializer='glorot_normal',kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=False, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = AveragePooling2D((5,5), strides=2,padding="same")(layers)
    #Block 5
    #Layer 4
    layers = tf.keras.layers.SpatialDropout2D(rate=0.1)(layers)
    layers = Conv2D(128, (1,1), strides=1,padding="same", kernel_initializer='glorot_normal',kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers)
    layers = ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=False, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = Concatenate()([layers, layers, layers])
    layers = GlobalAveragePooling2D(data_format="channels_last")(layers)
    
    #Block 6
    #Layer 5, FC, Softmax
  
    #FC
    layers = Dense(128,kernel_initializer='glorot_normal',kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers)
    layers = ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = Dense(64,kernel_initializer='glorot_normal',kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers)
    layers = ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = Dense(32,kernel_initializer='glorot_normal',kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers)
    layers = ReLU(negative_slope=0.1, threshold=0)(layers)
   
    #Softmax
    predictions = Dense(2, activation="softmax", name="output_1",kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers)
    model =tf.keras.Model(inputs = inputs, outputs=predictions)
    #Compile
    optimizer = tf.keras.optimizers.SGD(learning_rate=0.005, momentum=0.95)
    
    if compile:
        model.compile(optimizer= optimizer,
                      loss='binary_crossentropy',
                      metrics=['accuracy'])
        print ("Xunet")
    return model

# %% [markdown]
# ## Defining different functions to work with the architecture

# %%
def train(model, X_train, y_train, X_valid, y_valid, X_test, y_test, batch_size, epochs, initial_epoch = 0, model_name=""):
    start_time = tm.time()
    log_dir="D:/modelos/"+model_name+"_"+"{}".format(time())
    tensorboard = tf.keras.callbacks.TensorBoard(log_dir)
    filepath = log_dir+"/saved-model.hdf5"
    checkpoint = tf.keras.callbacks.ModelCheckpoint(
        filepath, 
        monitor='val_accuracy', 
        save_best_only=True, 
        mode='max',
        verbose=1
    )
    model.reset_states()
    history=model.fit(X_train, y_train, epochs=epochs, 
                        callbacks=[tensorboard,  checkpoint], 
                        batch_size=batch_size,
                        validation_data=(X_valid, y_valid),
                        initial_epoch=initial_epoch)
    
    metrics = model.evaluate(X_test, y_test, verbose=0)
    results_dir="D:/modelos//"+model_name+"/"
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
      
        plt.figure(figsize=(10, 10))
        #plt.subplot(1,2,1)
        #Plot training & validation accuracy values
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('Accuracy Vs Epochs')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.grid('on')
        plt.savefig(results_dir+'Accuracy_Xu_Net_'+model_name+'.eps', format='eps')
        plt.savefig(results_dir+'Accuracy_Xu_Net_'+model_name+'.svg', format='svg')
        plt.savefig(results_dir+'Accuracy_Xu_Net_'+model_name+'.pdf', format='pdf')
        plt.show()
        
        plt.figure(figsize=(10, 10))
        #plt.subplot(1,2,2)
        #Plot training & validation loss values
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('Loss Vs Epochs')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.grid('on')
        plt.savefig(results_dir+'Loss_Xu_Net_'+model_name+'.eps', format='eps')
        plt.savefig(results_dir+'Loss_Xu_Net_'+model_name+'.svg', format='svg')
        plt.savefig(results_dir+'Loss_Xu_Net_'+model_name+'.pdf', format='pdf')
        plt.show()

    TIME = tm.time() - start_time
    print("Time "+model_name+" = %s [seconds]" % TIME)
    return {k:v for k,v in zip (model.metrics_names, metrics)}

# %%
def Final_Results_Test(model,filename):

    if filename != ('train') and filename != ('validation'):
        print("\n\nBest")
        print(filename)
        model.load_weights(filename)
        loss,accuracy = model.evaluate(X_test, y_test,verbose=0)
        print(f'Loss={loss:.4f} y Accuracy={accuracy:0.4f}'+'\n')

# %% [markdown]
# ## Working with BOSSbase 1.01 WOW y PAYLOAD = 0.4bpp

# %% [markdown]
# In the README, there is a link to download the databases we use for the work. There are two databases BOSSbase 1.01 and Bows2+ BOSSbase 1.01, cover images and stego. You can choose the payload of 0.2 and 0.4 bpp for each of the databases.

# %%
#Train
X_train = np.load('data_load\X_train.npy')
y_train = np.load('data_load\y_train.npy')
#Valid
X_valid = np.load('data_load\X_valid.npy')
y_valid = np.load('data_load\y_valid.npy')
#Test
X_test = np.load('data_load\X_test.npy')
y_test = np.load('data_load\y_test.npy')

print(X_train.shape)
print(y_train.shape)
print(X_valid.shape)
print(y_valid.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (8000, 256, 256, 1)
# (8000, 2)
# (2000, 256, 256, 1)
# (2000, 2)
# (10000, 256, 256, 1)
# (10000, 2)

# %% [markdown]
# ## CNN name and algorithm

# %%
base_name="04S-UNIWARD"
m_name="XU_Net_strategy"

# %% [markdown]
# ## Training

# %%
model= Xu_Net_strategy() 
name="Model_"+m_name+"_"+base_name
_, history  = train(model, X_train, y_train, X_valid, y_valid, X_test, y_test, batch_size=4, epochs=400, model_name=name)
# Out:
# (5, 5, 1, 64)
# Xunet
# Epoch 1/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7987 - accuracy: 0.5016
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 208s 102ms/step - loss: 0.7987 - accuracy: 0.5016 - val_loss: 0.7929 - val_accuracy: 0.5000
# Epoch 2/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7884 - accuracy: 0.4940
# Epoch 2: val_accuracy did not improve from 0.50000
# 2000/2000 [==============================] - 206s 103ms/step - loss: 0.7884 - accuracy: 0.4940 - val_loss: 0.7859 - val_accuracy: 0.4995
# Epoch 3/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7811 - accuracy: 0.5107
# Epoch 3: val_accuracy did not improve from 0.50000
# 2000/2000 [==============================] - 207s 103ms/step - loss: 0.7811 - accuracy: 0.5107 - val_loss: 0.7782 - val_accuracy: 0.5000
# Epoch 4/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7743 - accuracy: 0.4991
# Epoch 4: val_accuracy improved from 0.50000 to 0.51750, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 207s 103ms/step - loss: 0.7743 - accuracy: 0.4991 - val_loss: 0.7736 - val_accuracy: 0.5175
# Epoch 5/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7672 - accuracy: 0.5150
# Epoch 5: val_accuracy did not improve from 0.51750
# 2000/2000 [==============================] - 209s 104ms/step - loss: 0.7672 - accuracy: 0.5150 - val_loss: 0.7685 - val_accuracy: 0.5160
# Epoch 6/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7576 - accuracy: 0.5326
# Epoch 6: val_accuracy improved from 0.51750 to 0.57000, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.7576 - accuracy: 0.5326 - val_loss: 0.7370 - val_accuracy: 0.5700
# Epoch 7/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7431 - accuracy: 0.5494
# Epoch 7: val_accuracy improved from 0.57000 to 0.59500, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.7431 - accuracy: 0.5494 - val_loss: 0.7300 - val_accuracy: 0.5950
# Epoch 8/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7319 - accuracy: 0.5669
# Epoch 8: val_accuracy improved from 0.59500 to 0.62750, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 209s 105ms/step - loss: 0.7319 - accuracy: 0.5669 - val_loss: 0.6885 - val_accuracy: 0.6275
# Epoch 9/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7200 - accuracy: 0.5798
# Epoch 9: val_accuracy did not improve from 0.62750
# 2000/2000 [==============================] - 209s 105ms/step - loss: 0.7200 - accuracy: 0.5798 - val_loss: 0.7022 - val_accuracy: 0.6050
# Epoch 10/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7124 - accuracy: 0.5932
# Epoch 10: val_accuracy improved from 0.62750 to 0.65050, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 207s 104ms/step - loss: 0.7124 - accuracy: 0.5932 - val_loss: 0.6481 - val_accuracy: 0.6505
# Epoch 11/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7014 - accuracy: 0.5980
# Epoch 11: val_accuracy did not improve from 0.65050
# 2000/2000 [==============================] - 207s 103ms/step - loss: 0.7014 - accuracy: 0.5980 - val_loss: 0.6677 - val_accuracy: 0.6055
# Epoch 12/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6888 - accuracy: 0.6111
# Epoch 12: val_accuracy did not improve from 0.65050
# 2000/2000 [==============================] - 204s 102ms/step - loss: 0.6888 - accuracy: 0.6111 - val_loss: 0.6635 - val_accuracy: 0.6495
# Epoch 13/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6824 - accuracy: 0.6144
# Epoch 13: val_accuracy improved from 0.65050 to 0.67300, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 203s 102ms/step - loss: 0.6824 - accuracy: 0.6144 - val_loss: 0.6223 - val_accuracy: 0.6730
# Epoch 14/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6669 - accuracy: 0.6310
# Epoch 14: val_accuracy did not improve from 0.67300
# 2000/2000 [==============================] - 203s 102ms/step - loss: 0.6669 - accuracy: 0.6310 - val_loss: 0.6512 - val_accuracy: 0.6560
# Epoch 15/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6618 - accuracy: 0.6291
# Epoch 15: val_accuracy improved from 0.67300 to 0.69300, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 203s 102ms/step - loss: 0.6618 - accuracy: 0.6291 - val_loss: 0.5731 - val_accuracy: 0.6930
# Epoch 16/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6457 - accuracy: 0.6411
# Epoch 16: val_accuracy did not improve from 0.69300
# 2000/2000 [==============================] - 204s 102ms/step - loss: 0.6457 - accuracy: 0.6411 - val_loss: 0.6445 - val_accuracy: 0.6665
# Epoch 17/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6468 - accuracy: 0.6356
# Epoch 17: val_accuracy did not improve from 0.69300
# 2000/2000 [==============================] - 207s 104ms/step - loss: 0.6468 - accuracy: 0.6356 - val_loss: 0.6448 - val_accuracy: 0.6535
# Epoch 18/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6338 - accuracy: 0.6485
# Epoch 18: val_accuracy improved from 0.69300 to 0.71500, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 207s 103ms/step - loss: 0.6338 - accuracy: 0.6485 - val_loss: 0.6003 - val_accuracy: 0.7150
# Epoch 19/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6273 - accuracy: 0.6490
# Epoch 19: val_accuracy did not improve from 0.71500
# 2000/2000 [==============================] - 207s 103ms/step - loss: 0.6273 - accuracy: 0.6490 - val_loss: 0.5735 - val_accuracy: 0.6940
# Epoch 20/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6231 - accuracy: 0.6550
# Epoch 20: val_accuracy did not improve from 0.71500
# 2000/2000 [==============================] - 207s 103ms/step - loss: 0.6231 - accuracy: 0.6550 - val_loss: 0.6102 - val_accuracy: 0.6165
# Epoch 21/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6152 - accuracy: 0.6626
# Epoch 21: val_accuracy improved from 0.71500 to 0.72650, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 208s 104ms/step - loss: 0.6152 - accuracy: 0.6626 - val_loss: 0.5525 - val_accuracy: 0.7265
# Epoch 22/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6069 - accuracy: 0.6661
# Epoch 22: val_accuracy improved from 0.72650 to 0.74750, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.6069 - accuracy: 0.6661 - val_loss: 0.5072 - val_accuracy: 0.7475
# Epoch 23/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5996 - accuracy: 0.6737
# Epoch 23: val_accuracy did not improve from 0.74750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5996 - accuracy: 0.6737 - val_loss: 0.5857 - val_accuracy: 0.7405
# Epoch 24/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5955 - accuracy: 0.6854
# Epoch 24: val_accuracy did not improve from 0.74750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5955 - accuracy: 0.6854 - val_loss: 0.5430 - val_accuracy: 0.7240
# Epoch 25/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5848 - accuracy: 0.6864
# Epoch 25: val_accuracy did not improve from 0.74750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5848 - accuracy: 0.6864 - val_loss: 0.5359 - val_accuracy: 0.7285
# Epoch 26/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5811 - accuracy: 0.6946
# Epoch 26: val_accuracy did not improve from 0.74750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5811 - accuracy: 0.6946 - val_loss: 0.5843 - val_accuracy: 0.6860
# Epoch 27/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5701 - accuracy: 0.7060
# Epoch 27: val_accuracy did not improve from 0.74750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5701 - accuracy: 0.7060 - val_loss: 0.5685 - val_accuracy: 0.7315
# Epoch 28/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5661 - accuracy: 0.7057
# Epoch 28: val_accuracy improved from 0.74750 to 0.76050, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 211s 105ms/step - loss: 0.5661 - accuracy: 0.7057 - val_loss: 0.5028 - val_accuracy: 0.7605
# Epoch 29/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5600 - accuracy: 0.7097
# Epoch 29: val_accuracy improved from 0.76050 to 0.76650, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5600 - accuracy: 0.7097 - val_loss: 0.4903 - val_accuracy: 0.7665
# Epoch 30/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5544 - accuracy: 0.7186
# Epoch 30: val_accuracy did not improve from 0.76650
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5544 - accuracy: 0.7186 - val_loss: 0.5439 - val_accuracy: 0.7175
# Epoch 31/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5526 - accuracy: 0.7193
# Epoch 31: val_accuracy did not improve from 0.76650
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5526 - accuracy: 0.7193 - val_loss: 0.5453 - val_accuracy: 0.7605
# Epoch 32/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5516 - accuracy: 0.7193
# Epoch 32: val_accuracy did not improve from 0.76650
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5516 - accuracy: 0.7193 - val_loss: 0.7809 - val_accuracy: 0.6545
# Epoch 33/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5529 - accuracy: 0.7165
# Epoch 33: val_accuracy improved from 0.76650 to 0.77050, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5529 - accuracy: 0.7165 - val_loss: 0.5068 - val_accuracy: 0.7705
# Epoch 34/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5470 - accuracy: 0.7322
# Epoch 34: val_accuracy improved from 0.77050 to 0.78350, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5470 - accuracy: 0.7322 - val_loss: 0.5302 - val_accuracy: 0.7835
# Epoch 35/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5418 - accuracy: 0.7276
# Epoch 35: val_accuracy did not improve from 0.78350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5418 - accuracy: 0.7276 - val_loss: 0.7246 - val_accuracy: 0.6385
# Epoch 36/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5469 - accuracy: 0.7264
# Epoch 36: val_accuracy did not improve from 0.78350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5469 - accuracy: 0.7264 - val_loss: 0.5335 - val_accuracy: 0.7765
# Epoch 37/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5350 - accuracy: 0.7284
# Epoch 37: val_accuracy did not improve from 0.78350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5350 - accuracy: 0.7284 - val_loss: 0.5435 - val_accuracy: 0.7550
# Epoch 38/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5369 - accuracy: 0.7345
# Epoch 38: val_accuracy did not improve from 0.78350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5369 - accuracy: 0.7345 - val_loss: 0.4934 - val_accuracy: 0.7825
# Epoch 39/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5409 - accuracy: 0.7306
# Epoch 39: val_accuracy improved from 0.78350 to 0.79600, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5409 - accuracy: 0.7306 - val_loss: 0.4800 - val_accuracy: 0.7960
# Epoch 40/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5348 - accuracy: 0.7399
# Epoch 40: val_accuracy did not improve from 0.79600
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5348 - accuracy: 0.7399 - val_loss: 0.5224 - val_accuracy: 0.7755
# Epoch 41/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5314 - accuracy: 0.7318
# Epoch 41: val_accuracy improved from 0.79600 to 0.80300, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5314 - accuracy: 0.7318 - val_loss: 0.4935 - val_accuracy: 0.8030
# Epoch 42/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5387 - accuracy: 0.7293
# Epoch 42: val_accuracy did not improve from 0.80300
# 2000/2000 [==============================] - 211s 105ms/step - loss: 0.5387 - accuracy: 0.7293 - val_loss: 0.4956 - val_accuracy: 0.7515
# Epoch 43/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5369 - accuracy: 0.7294
# Epoch 43: val_accuracy did not improve from 0.80300
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5369 - accuracy: 0.7294 - val_loss: 0.4871 - val_accuracy: 0.7775
# Epoch 44/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5353 - accuracy: 0.7370
# Epoch 44: val_accuracy did not improve from 0.80300
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5353 - accuracy: 0.7370 - val_loss: 0.5992 - val_accuracy: 0.7490
# Epoch 45/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5286 - accuracy: 0.7386
# Epoch 45: val_accuracy did not improve from 0.80300
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5286 - accuracy: 0.7386 - val_loss: 0.5225 - val_accuracy: 0.7750
# Epoch 46/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5385 - accuracy: 0.7359
# Epoch 46: val_accuracy did not improve from 0.80300
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5385 - accuracy: 0.7359 - val_loss: 0.5214 - val_accuracy: 0.7980
# Epoch 47/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5328 - accuracy: 0.7414
# Epoch 47: val_accuracy did not improve from 0.80300
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5328 - accuracy: 0.7414 - val_loss: 0.5719 - val_accuracy: 0.6980
# Epoch 48/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5346 - accuracy: 0.7398
# Epoch 48: val_accuracy did not improve from 0.80300
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5346 - accuracy: 0.7398 - val_loss: 0.6766 - val_accuracy: 0.7005
# Epoch 49/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5304 - accuracy: 0.7402
# Epoch 49: val_accuracy did not improve from 0.80300
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5304 - accuracy: 0.7402 - val_loss: 0.4477 - val_accuracy: 0.7960
# Epoch 50/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5288 - accuracy: 0.7470
# Epoch 50: val_accuracy did not improve from 0.80300
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5288 - accuracy: 0.7470 - val_loss: 0.5137 - val_accuracy: 0.7865
# Epoch 51/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5168 - accuracy: 0.7519
# Epoch 51: val_accuracy did not improve from 0.80300
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5168 - accuracy: 0.7519 - val_loss: 0.7606 - val_accuracy: 0.6165
# Epoch 52/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5181 - accuracy: 0.7459
# Epoch 52: val_accuracy improved from 0.80300 to 0.81650, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5181 - accuracy: 0.7459 - val_loss: 0.4482 - val_accuracy: 0.8165
# Epoch 53/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5206 - accuracy: 0.7519
# Epoch 53: val_accuracy did not improve from 0.81650
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5206 - accuracy: 0.7519 - val_loss: 0.5384 - val_accuracy: 0.7310
# Epoch 54/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5249 - accuracy: 0.7479
# Epoch 54: val_accuracy did not improve from 0.81650
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5249 - accuracy: 0.7479 - val_loss: 0.5962 - val_accuracy: 0.7745
# Epoch 55/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5220 - accuracy: 0.7473
# Epoch 55: val_accuracy improved from 0.81650 to 0.81850, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5220 - accuracy: 0.7473 - val_loss: 0.4492 - val_accuracy: 0.8185
# Epoch 56/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5176 - accuracy: 0.7483
# Epoch 56: val_accuracy did not improve from 0.81850
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5176 - accuracy: 0.7483 - val_loss: 0.5196 - val_accuracy: 0.7670
# Epoch 57/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5182 - accuracy: 0.7446
# Epoch 57: val_accuracy did not improve from 0.81850
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5182 - accuracy: 0.7446 - val_loss: 0.5661 - val_accuracy: 0.7355
# Epoch 58/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5156 - accuracy: 0.7602
# Epoch 58: val_accuracy did not improve from 0.81850
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5156 - accuracy: 0.7602 - val_loss: 0.5173 - val_accuracy: 0.7845
# Epoch 59/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5210 - accuracy: 0.7487
# Epoch 59: val_accuracy did not improve from 0.81850
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5210 - accuracy: 0.7487 - val_loss: 0.4595 - val_accuracy: 0.8005
# Epoch 60/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5068 - accuracy: 0.7604
# Epoch 60: val_accuracy improved from 0.81850 to 0.82350, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5068 - accuracy: 0.7604 - val_loss: 0.4289 - val_accuracy: 0.8235
# Epoch 61/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5194 - accuracy: 0.7538
# Epoch 61: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5194 - accuracy: 0.7538 - val_loss: 0.4777 - val_accuracy: 0.7785
# Epoch 62/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5145 - accuracy: 0.7602
# Epoch 62: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5145 - accuracy: 0.7602 - val_loss: 0.4933 - val_accuracy: 0.7925
# Epoch 63/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5106 - accuracy: 0.7542
# Epoch 63: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5106 - accuracy: 0.7542 - val_loss: 0.5101 - val_accuracy: 0.7980
# Epoch 64/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5087 - accuracy: 0.7610
# Epoch 64: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5087 - accuracy: 0.7610 - val_loss: 0.5190 - val_accuracy: 0.7570
# Epoch 65/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5144 - accuracy: 0.7538
# Epoch 65: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5144 - accuracy: 0.7538 - val_loss: 0.4928 - val_accuracy: 0.7530
# Epoch 66/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5163 - accuracy: 0.7541
# Epoch 66: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5163 - accuracy: 0.7541 - val_loss: 0.5750 - val_accuracy: 0.7260
# Epoch 67/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5133 - accuracy: 0.7564
# Epoch 67: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5133 - accuracy: 0.7564 - val_loss: 0.5280 - val_accuracy: 0.7955
# Epoch 68/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5155 - accuracy: 0.7574
# Epoch 68: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5155 - accuracy: 0.7574 - val_loss: 0.7933 - val_accuracy: 0.7285
# Epoch 69/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5050 - accuracy: 0.7579
# Epoch 69: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5050 - accuracy: 0.7579 - val_loss: 0.6993 - val_accuracy: 0.7605
# Epoch 70/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5054 - accuracy: 0.7628
# Epoch 70: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5054 - accuracy: 0.7628 - val_loss: 0.5595 - val_accuracy: 0.7835
# Epoch 71/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5156 - accuracy: 0.7565
# Epoch 71: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5156 - accuracy: 0.7565 - val_loss: 0.5389 - val_accuracy: 0.7540
# Epoch 72/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5119 - accuracy: 0.7594
# Epoch 72: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5119 - accuracy: 0.7594 - val_loss: 0.5344 - val_accuracy: 0.7755
# Epoch 73/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5076 - accuracy: 0.7575
# Epoch 73: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5076 - accuracy: 0.7575 - val_loss: 0.4466 - val_accuracy: 0.7975
# Epoch 74/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5161 - accuracy: 0.7639
# Epoch 74: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5161 - accuracy: 0.7639 - val_loss: 0.6829 - val_accuracy: 0.7160
# Epoch 75/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5073 - accuracy: 0.7616
# Epoch 75: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5073 - accuracy: 0.7616 - val_loss: 0.5193 - val_accuracy: 0.7935
# Epoch 76/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5016 - accuracy: 0.7678
# Epoch 76: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5016 - accuracy: 0.7678 - val_loss: 0.5121 - val_accuracy: 0.7510
# Epoch 77/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5067 - accuracy: 0.7591
# Epoch 77: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5067 - accuracy: 0.7591 - val_loss: 0.5628 - val_accuracy: 0.7465
# Epoch 78/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5087 - accuracy: 0.7580
# Epoch 78: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5087 - accuracy: 0.7580 - val_loss: 0.5274 - val_accuracy: 0.8080
# Epoch 79/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5099 - accuracy: 0.7596
# Epoch 79: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5099 - accuracy: 0.7596 - val_loss: 0.4872 - val_accuracy: 0.7730
# Epoch 80/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5074 - accuracy: 0.7635
# Epoch 80: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5074 - accuracy: 0.7635 - val_loss: 0.4963 - val_accuracy: 0.8080
# Epoch 81/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5090 - accuracy: 0.7641
# Epoch 81: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5090 - accuracy: 0.7641 - val_loss: 0.4848 - val_accuracy: 0.8025
# Epoch 82/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5086 - accuracy: 0.7644
# Epoch 82: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5086 - accuracy: 0.7644 - val_loss: 0.4784 - val_accuracy: 0.8150
# Epoch 83/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5018 - accuracy: 0.7747
# Epoch 83: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5018 - accuracy: 0.7747 - val_loss: 0.4605 - val_accuracy: 0.8220
# Epoch 84/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5025 - accuracy: 0.7674
# Epoch 84: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5025 - accuracy: 0.7674 - val_loss: 0.6821 - val_accuracy: 0.7540
# Epoch 85/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4999 - accuracy: 0.7669
# Epoch 85: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4999 - accuracy: 0.7669 - val_loss: 0.4327 - val_accuracy: 0.8090
# Epoch 86/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5055 - accuracy: 0.7636
# Epoch 86: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 209s 105ms/step - loss: 0.5055 - accuracy: 0.7636 - val_loss: 0.4776 - val_accuracy: 0.7935
# Epoch 87/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5070 - accuracy: 0.7546
# Epoch 87: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5070 - accuracy: 0.7546 - val_loss: 0.6429 - val_accuracy: 0.6520
# Epoch 88/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5056 - accuracy: 0.7634
# Epoch 88: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5056 - accuracy: 0.7634 - val_loss: 0.4625 - val_accuracy: 0.8075
# Epoch 89/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4999 - accuracy: 0.7685
# Epoch 89: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4999 - accuracy: 0.7685 - val_loss: 0.5064 - val_accuracy: 0.7755
# Epoch 90/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4959 - accuracy: 0.7751
# Epoch 90: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4959 - accuracy: 0.7751 - val_loss: 0.4762 - val_accuracy: 0.8165
# Epoch 91/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4979 - accuracy: 0.7689
# Epoch 91: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4979 - accuracy: 0.7689 - val_loss: 0.5164 - val_accuracy: 0.8005
# Epoch 92/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4973 - accuracy: 0.7746
# Epoch 92: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4973 - accuracy: 0.7746 - val_loss: 0.4628 - val_accuracy: 0.8195
# Epoch 93/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4983 - accuracy: 0.7734
# Epoch 93: val_accuracy did not improve from 0.82350
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4983 - accuracy: 0.7734 - val_loss: 0.5224 - val_accuracy: 0.7905
# Epoch 94/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4904 - accuracy: 0.7765
# Epoch 94: val_accuracy improved from 0.82350 to 0.82900, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4904 - accuracy: 0.7765 - val_loss: 0.4679 - val_accuracy: 0.8290
# Epoch 95/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4984 - accuracy: 0.7699
# Epoch 95: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4984 - accuracy: 0.7699 - val_loss: 0.4816 - val_accuracy: 0.8095
# Epoch 96/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5103 - accuracy: 0.7638
# Epoch 96: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5103 - accuracy: 0.7638 - val_loss: 0.4835 - val_accuracy: 0.8145
# Epoch 97/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5005 - accuracy: 0.7691
# Epoch 97: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5005 - accuracy: 0.7691 - val_loss: 0.6109 - val_accuracy: 0.7285
# Epoch 98/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5059 - accuracy: 0.7701
# Epoch 98: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5059 - accuracy: 0.7701 - val_loss: 0.6572 - val_accuracy: 0.6860
# Epoch 99/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4963 - accuracy: 0.7732
# Epoch 99: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4963 - accuracy: 0.7732 - val_loss: 0.6524 - val_accuracy: 0.7620
# Epoch 100/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4998 - accuracy: 0.7765
# Epoch 100: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4998 - accuracy: 0.7765 - val_loss: 0.6248 - val_accuracy: 0.7675
# Epoch 101/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5056 - accuracy: 0.7699
# Epoch 101: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5056 - accuracy: 0.7699 - val_loss: 0.4630 - val_accuracy: 0.8070
# Epoch 102/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4980 - accuracy: 0.7729
# Epoch 102: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4980 - accuracy: 0.7729 - val_loss: 0.4278 - val_accuracy: 0.8210
# Epoch 103/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4996 - accuracy: 0.7732
# Epoch 103: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4996 - accuracy: 0.7732 - val_loss: 0.4942 - val_accuracy: 0.8095
# Epoch 104/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5035 - accuracy: 0.7697
# Epoch 104: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5035 - accuracy: 0.7697 - val_loss: 0.4587 - val_accuracy: 0.8230
# Epoch 105/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5038 - accuracy: 0.7722
# Epoch 105: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5038 - accuracy: 0.7722 - val_loss: 0.4572 - val_accuracy: 0.8105
# Epoch 106/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4981 - accuracy: 0.7678
# Epoch 106: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4981 - accuracy: 0.7678 - val_loss: 0.6821 - val_accuracy: 0.6870
# Epoch 107/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5003 - accuracy: 0.7724
# Epoch 107: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5003 - accuracy: 0.7724 - val_loss: 0.4952 - val_accuracy: 0.8230
# Epoch 108/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4976 - accuracy: 0.7750
# Epoch 108: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4976 - accuracy: 0.7750 - val_loss: 0.4731 - val_accuracy: 0.8195
# Epoch 109/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4980 - accuracy: 0.7759
# Epoch 109: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4980 - accuracy: 0.7759 - val_loss: 0.4795 - val_accuracy: 0.7860
# Epoch 110/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4920 - accuracy: 0.7760
# Epoch 110: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4920 - accuracy: 0.7760 - val_loss: 0.4735 - val_accuracy: 0.8195
# Epoch 111/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5054 - accuracy: 0.7690
# Epoch 111: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5054 - accuracy: 0.7690 - val_loss: 0.5029 - val_accuracy: 0.7585
# Epoch 112/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5101 - accuracy: 0.7685
# Epoch 112: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5101 - accuracy: 0.7685 - val_loss: 0.4387 - val_accuracy: 0.8070
# Epoch 113/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4952 - accuracy: 0.7805
# Epoch 113: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4952 - accuracy: 0.7805 - val_loss: 0.5805 - val_accuracy: 0.7005
# Epoch 114/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4923 - accuracy: 0.7796
# Epoch 114: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4923 - accuracy: 0.7796 - val_loss: 0.4867 - val_accuracy: 0.8170
# Epoch 115/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5033 - accuracy: 0.7753
# Epoch 115: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5033 - accuracy: 0.7753 - val_loss: 0.5794 - val_accuracy: 0.7890
# Epoch 116/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5100 - accuracy: 0.7670
# Epoch 116: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5100 - accuracy: 0.7670 - val_loss: 0.4470 - val_accuracy: 0.8155
# Epoch 117/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4945 - accuracy: 0.7763
# Epoch 117: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4945 - accuracy: 0.7763 - val_loss: 0.4918 - val_accuracy: 0.8120
# Epoch 118/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5014 - accuracy: 0.7710
# Epoch 118: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5014 - accuracy: 0.7710 - val_loss: 0.4668 - val_accuracy: 0.8100
# Epoch 119/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5032 - accuracy: 0.7745
# Epoch 119: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5032 - accuracy: 0.7745 - val_loss: 0.5694 - val_accuracy: 0.8225
# Epoch 120/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4936 - accuracy: 0.7789
# Epoch 120: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4936 - accuracy: 0.7789 - val_loss: 0.4667 - val_accuracy: 0.7905
# Epoch 121/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5092 - accuracy: 0.7695
# Epoch 121: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5092 - accuracy: 0.7695 - val_loss: 0.4527 - val_accuracy: 0.8270
# Epoch 122/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4966 - accuracy: 0.7780
# Epoch 122: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4966 - accuracy: 0.7780 - val_loss: 0.4800 - val_accuracy: 0.8135
# Epoch 123/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7794
# Epoch 123: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4907 - accuracy: 0.7794 - val_loss: 0.9219 - val_accuracy: 0.7240
# Epoch 124/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4958 - accuracy: 0.7811
# Epoch 124: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4958 - accuracy: 0.7811 - val_loss: 0.6789 - val_accuracy: 0.6855
# Epoch 125/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4923 - accuracy: 0.7837
# Epoch 125: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4923 - accuracy: 0.7837 - val_loss: 0.5772 - val_accuracy: 0.7440
# Epoch 126/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5010 - accuracy: 0.7815
# Epoch 126: val_accuracy did not improve from 0.82900
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5010 - accuracy: 0.7815 - val_loss: 0.4657 - val_accuracy: 0.8105
# Epoch 127/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4929 - accuracy: 0.7830
# Epoch 127: val_accuracy improved from 0.82900 to 0.83750, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4929 - accuracy: 0.7830 - val_loss: 0.4185 - val_accuracy: 0.8375
# Epoch 128/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4916 - accuracy: 0.7781
# Epoch 128: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4916 - accuracy: 0.7781 - val_loss: 0.4736 - val_accuracy: 0.8260
# Epoch 129/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4968 - accuracy: 0.7745
# Epoch 129: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4968 - accuracy: 0.7745 - val_loss: 0.4908 - val_accuracy: 0.7805
# Epoch 130/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4987 - accuracy: 0.7768
# Epoch 130: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4987 - accuracy: 0.7768 - val_loss: 0.4579 - val_accuracy: 0.8185
# Epoch 131/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4869 - accuracy: 0.7797
# Epoch 131: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4869 - accuracy: 0.7797 - val_loss: 0.5126 - val_accuracy: 0.7930
# Epoch 132/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4998 - accuracy: 0.7749
# Epoch 132: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4998 - accuracy: 0.7749 - val_loss: 0.5018 - val_accuracy: 0.8150
# Epoch 133/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4845 - accuracy: 0.7876
# Epoch 133: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4845 - accuracy: 0.7876 - val_loss: 0.5135 - val_accuracy: 0.8220
# Epoch 134/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4938 - accuracy: 0.7834
# Epoch 134: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4938 - accuracy: 0.7834 - val_loss: 0.6011 - val_accuracy: 0.7675
# Epoch 135/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4940 - accuracy: 0.7836
# Epoch 135: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4940 - accuracy: 0.7836 - val_loss: 0.6345 - val_accuracy: 0.7740
# Epoch 136/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4986 - accuracy: 0.7769
# Epoch 136: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4986 - accuracy: 0.7769 - val_loss: 0.6434 - val_accuracy: 0.6775
# Epoch 137/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4906 - accuracy: 0.7799
# Epoch 137: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4906 - accuracy: 0.7799 - val_loss: 0.4223 - val_accuracy: 0.8230
# Epoch 138/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4940 - accuracy: 0.7775
# Epoch 138: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4940 - accuracy: 0.7775 - val_loss: 0.4220 - val_accuracy: 0.8350
# Epoch 139/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4905 - accuracy: 0.7815
# Epoch 139: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4905 - accuracy: 0.7815 - val_loss: 0.5500 - val_accuracy: 0.7975
# Epoch 140/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4934 - accuracy: 0.7878
# Epoch 140: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4934 - accuracy: 0.7878 - val_loss: 0.5384 - val_accuracy: 0.8070
# Epoch 141/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4999 - accuracy: 0.7784
# Epoch 141: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4999 - accuracy: 0.7784 - val_loss: 0.5314 - val_accuracy: 0.8105
# Epoch 142/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5016 - accuracy: 0.7749
# Epoch 142: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5016 - accuracy: 0.7749 - val_loss: 0.4865 - val_accuracy: 0.8120
# Epoch 143/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4932 - accuracy: 0.7854
# Epoch 143: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4932 - accuracy: 0.7854 - val_loss: 0.8817 - val_accuracy: 0.7565
# Epoch 144/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.7789
# Epoch 144: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.5000 - accuracy: 0.7789 - val_loss: 0.5171 - val_accuracy: 0.7635
# Epoch 145/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4961 - accuracy: 0.7887
# Epoch 145: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4961 - accuracy: 0.7887 - val_loss: 0.4597 - val_accuracy: 0.8245
# Epoch 146/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4919 - accuracy: 0.7886
# Epoch 146: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4919 - accuracy: 0.7886 - val_loss: 0.4908 - val_accuracy: 0.8315
# Epoch 147/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4919 - accuracy: 0.7894
# Epoch 147: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4919 - accuracy: 0.7894 - val_loss: 0.4766 - val_accuracy: 0.8125
# Epoch 148/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4990 - accuracy: 0.7841
# Epoch 148: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4990 - accuracy: 0.7841 - val_loss: 0.4785 - val_accuracy: 0.8350
# Epoch 149/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4886 - accuracy: 0.7901
# Epoch 149: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4886 - accuracy: 0.7901 - val_loss: 0.4608 - val_accuracy: 0.8300
# Epoch 150/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4864 - accuracy: 0.7864
# Epoch 150: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4864 - accuracy: 0.7864 - val_loss: 0.4512 - val_accuracy: 0.8120
# Epoch 151/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4938 - accuracy: 0.7893
# Epoch 151: val_accuracy did not improve from 0.83750
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4938 - accuracy: 0.7893 - val_loss: 0.7744 - val_accuracy: 0.7960
# Epoch 152/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4988 - accuracy: 0.7810
# Epoch 152: val_accuracy improved from 0.83750 to 0.84450, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4988 - accuracy: 0.7810 - val_loss: 0.4173 - val_accuracy: 0.8445
# Epoch 153/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4892 - accuracy: 0.7897
# Epoch 153: val_accuracy did not improve from 0.84450
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4892 - accuracy: 0.7897 - val_loss: 0.5587 - val_accuracy: 0.8045
# Epoch 154/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4900 - accuracy: 0.7884
# Epoch 154: val_accuracy did not improve from 0.84450
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4900 - accuracy: 0.7884 - val_loss: 0.6768 - val_accuracy: 0.6980
# Epoch 155/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4968 - accuracy: 0.7836
# Epoch 155: val_accuracy did not improve from 0.84450
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4968 - accuracy: 0.7836 - val_loss: 0.4910 - val_accuracy: 0.8230
# Epoch 156/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4899 - accuracy: 0.7891
# Epoch 156: val_accuracy did not improve from 0.84450
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4899 - accuracy: 0.7891 - val_loss: 0.5916 - val_accuracy: 0.8065
# Epoch 157/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4890 - accuracy: 0.7831
# Epoch 157: val_accuracy did not improve from 0.84450
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4890 - accuracy: 0.7831 - val_loss: 0.5687 - val_accuracy: 0.7825
# Epoch 158/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4911 - accuracy: 0.7834
# Epoch 158: val_accuracy did not improve from 0.84450
# ...
# 2000/2000 [==============================] - 211s 106ms/step - loss: 0.4864 - accuracy: 0.8127 - val_loss: 0.4910 - val_accuracy: 0.8115
# Epoch 348/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4920 - accuracy: 0.8066
# Epoch 348: val_accuracy did not improve from 0.84650
# 2000/2000 [==============================] - 211s 105ms/step - loss: 0.4920 - accuracy: 0.8066 - val_loss: 0.5503 - val_accuracy: 0.7595
# Epoch 349/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4870 - accuracy: 0.8058
# Epoch 349: val_accuracy did not improve from 0.84650
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4870 - accuracy: 0.8058 - val_loss: 0.5958 - val_accuracy: 0.7595
# Epoch 350/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4935 - accuracy: 0.8048
# Epoch 350: val_accuracy did not improve from 0.84650
# 2000/2000 [==============================] - 211s 105ms/step - loss: 0.4935 - accuracy: 0.8048 - val_loss: 0.5818 - val_accuracy: 0.7550
# Epoch 351/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4894 - accuracy: 0.8084
# Epoch 351: val_accuracy did not improve from 0.84650
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4894 - accuracy: 0.8084 - val_loss: 0.4658 - val_accuracy: 0.8230
# Epoch 352/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4804 - accuracy: 0.8173
# Epoch 352: val_accuracy did not improve from 0.84650
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4804 - accuracy: 0.8173 - val_loss: 0.4327 - val_accuracy: 0.8395
# Epoch 353/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4898 - accuracy: 0.8085
# Epoch 353: val_accuracy improved from 0.84650 to 0.85000, saving model to D:/modelos/Model_XU_Net_strategy_04S-UNIWARD_1728513256.2011118\saved-model.hdf5
# 2000/2000 [==============================] - 211s 105ms/step - loss: 0.4898 - accuracy: 0.8085 - val_loss: 0.4285 - val_accuracy: 0.8500
# Epoch 354/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4876 - accuracy: 0.8092
# Epoch 354: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 211s 105ms/step - loss: 0.4876 - accuracy: 0.8092 - val_loss: 0.5219 - val_accuracy: 0.7865
# Epoch 355/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4800 - accuracy: 0.8127
# Epoch 355: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4800 - accuracy: 0.8127 - val_loss: 0.4865 - val_accuracy: 0.8385
# Epoch 356/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4884 - accuracy: 0.8140
# Epoch 356: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4884 - accuracy: 0.8140 - val_loss: 0.4747 - val_accuracy: 0.8225
# Epoch 357/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4843 - accuracy: 0.8144
# Epoch 357: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4843 - accuracy: 0.8144 - val_loss: 0.4321 - val_accuracy: 0.8500
# Epoch 358/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4825 - accuracy: 0.8119
# Epoch 358: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4825 - accuracy: 0.8119 - val_loss: 0.5322 - val_accuracy: 0.8165
# Epoch 359/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4798 - accuracy: 0.8117
# Epoch 359: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 211s 105ms/step - loss: 0.4798 - accuracy: 0.8117 - val_loss: 0.5381 - val_accuracy: 0.8205
# Epoch 360/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4934 - accuracy: 0.8056
# Epoch 360: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 211s 105ms/step - loss: 0.4934 - accuracy: 0.8056 - val_loss: 0.5858 - val_accuracy: 0.8250
# Epoch 361/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4875 - accuracy: 0.8051
# Epoch 361: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4875 - accuracy: 0.8051 - val_loss: 1.2050 - val_accuracy: 0.7445
# Epoch 362/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4798 - accuracy: 0.8125
# Epoch 362: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4798 - accuracy: 0.8125 - val_loss: 0.5354 - val_accuracy: 0.8235
# Epoch 363/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4913 - accuracy: 0.8065
# Epoch 363: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4913 - accuracy: 0.8065 - val_loss: 0.5292 - val_accuracy: 0.8385
# Epoch 364/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4840 - accuracy: 0.8112
# Epoch 364: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4840 - accuracy: 0.8112 - val_loss: 0.5906 - val_accuracy: 0.7695
# Epoch 365/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4800 - accuracy: 0.8160
# Epoch 365: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 211s 105ms/step - loss: 0.4800 - accuracy: 0.8160 - val_loss: 0.6353 - val_accuracy: 0.7890
# Epoch 366/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4864 - accuracy: 0.8066
# Epoch 366: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4864 - accuracy: 0.8066 - val_loss: 0.4738 - val_accuracy: 0.8435
# Epoch 367/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4933 - accuracy: 0.8091
# Epoch 367: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4933 - accuracy: 0.8091 - val_loss: 0.5349 - val_accuracy: 0.8115
# Epoch 368/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4899 - accuracy: 0.8117
# Epoch 368: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4899 - accuracy: 0.8117 - val_loss: 0.5527 - val_accuracy: 0.7985
# Epoch 369/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4851 - accuracy: 0.8149
# Epoch 369: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4851 - accuracy: 0.8149 - val_loss: 0.4536 - val_accuracy: 0.8360
# Epoch 370/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4825 - accuracy: 0.8071
# Epoch 370: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 211s 105ms/step - loss: 0.4825 - accuracy: 0.8071 - val_loss: 0.4898 - val_accuracy: 0.8115
# Epoch 371/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4816 - accuracy: 0.8109
# Epoch 371: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4816 - accuracy: 0.8109 - val_loss: 0.5043 - val_accuracy: 0.8160
# Epoch 372/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4910 - accuracy: 0.8065
# Epoch 372: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4910 - accuracy: 0.8065 - val_loss: 0.6040 - val_accuracy: 0.8190
# Epoch 373/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4816 - accuracy: 0.8120
# Epoch 373: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4816 - accuracy: 0.8120 - val_loss: 0.4929 - val_accuracy: 0.8245
# Epoch 374/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4815 - accuracy: 0.8094
# Epoch 374: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 206s 103ms/step - loss: 0.4815 - accuracy: 0.8094 - val_loss: 0.5014 - val_accuracy: 0.8105
# Epoch 375/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4802 - accuracy: 0.8126
# Epoch 375: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 206s 103ms/step - loss: 0.4802 - accuracy: 0.8126 - val_loss: 0.7489 - val_accuracy: 0.7070
# Epoch 376/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4830 - accuracy: 0.8136
# Epoch 376: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 207s 103ms/step - loss: 0.4830 - accuracy: 0.8136 - val_loss: 0.6058 - val_accuracy: 0.7945
# Epoch 377/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4749 - accuracy: 0.8110
# Epoch 377: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 206s 103ms/step - loss: 0.4749 - accuracy: 0.8110 - val_loss: 0.4871 - val_accuracy: 0.8025
# Epoch 378/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4901 - accuracy: 0.8112
# Epoch 378: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 206s 103ms/step - loss: 0.4901 - accuracy: 0.8112 - val_loss: 0.4696 - val_accuracy: 0.8320
# Epoch 379/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4872 - accuracy: 0.8108
# Epoch 379: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 209s 105ms/step - loss: 0.4872 - accuracy: 0.8108 - val_loss: 0.5704 - val_accuracy: 0.7770
# Epoch 380/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4899 - accuracy: 0.8070
# Epoch 380: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 208s 104ms/step - loss: 0.4899 - accuracy: 0.8070 - val_loss: 0.7040 - val_accuracy: 0.7620
# Epoch 381/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4853 - accuracy: 0.8084
# Epoch 381: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 207s 104ms/step - loss: 0.4853 - accuracy: 0.8084 - val_loss: 0.5296 - val_accuracy: 0.7965
# Epoch 382/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4859 - accuracy: 0.8115
# Epoch 382: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 208s 104ms/step - loss: 0.4859 - accuracy: 0.8115 - val_loss: 0.5165 - val_accuracy: 0.8055
# Epoch 383/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4843 - accuracy: 0.8164
# Epoch 383: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 207s 103ms/step - loss: 0.4843 - accuracy: 0.8164 - val_loss: 0.4702 - val_accuracy: 0.8405
# Epoch 384/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4871 - accuracy: 0.8080
# Epoch 384: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 209s 105ms/step - loss: 0.4871 - accuracy: 0.8080 - val_loss: 0.4588 - val_accuracy: 0.8185
# Epoch 385/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4886 - accuracy: 0.8077
# Epoch 385: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 211s 105ms/step - loss: 0.4886 - accuracy: 0.8077 - val_loss: 0.4639 - val_accuracy: 0.8420
# Epoch 386/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4773 - accuracy: 0.8173
# Epoch 386: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 208s 104ms/step - loss: 0.4773 - accuracy: 0.8173 - val_loss: 0.5522 - val_accuracy: 0.7770
# Epoch 387/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4990 - accuracy: 0.8080
# Epoch 387: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 207s 104ms/step - loss: 0.4990 - accuracy: 0.8080 - val_loss: 0.4613 - val_accuracy: 0.8300
# Epoch 388/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4810 - accuracy: 0.8145
# Epoch 388: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 212s 106ms/step - loss: 0.4810 - accuracy: 0.8145 - val_loss: 0.5595 - val_accuracy: 0.7910
# Epoch 389/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4845 - accuracy: 0.8163
# Epoch 389: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 209s 105ms/step - loss: 0.4845 - accuracy: 0.8163 - val_loss: 0.4472 - val_accuracy: 0.8385
# Epoch 390/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4832 - accuracy: 0.8144
# Epoch 390: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 209s 105ms/step - loss: 0.4832 - accuracy: 0.8144 - val_loss: 0.6646 - val_accuracy: 0.7380
# Epoch 391/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4784 - accuracy: 0.8159
# Epoch 391: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 208s 104ms/step - loss: 0.4784 - accuracy: 0.8159 - val_loss: 0.5164 - val_accuracy: 0.8450
# Epoch 392/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4846 - accuracy: 0.8179
# Epoch 392: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 211s 105ms/step - loss: 0.4846 - accuracy: 0.8179 - val_loss: 0.5959 - val_accuracy: 0.7535
# Epoch 393/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4944 - accuracy: 0.8023
# Epoch 393: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 208s 104ms/step - loss: 0.4944 - accuracy: 0.8023 - val_loss: 0.5524 - val_accuracy: 0.8280
# Epoch 394/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4796 - accuracy: 0.8181
# Epoch 394: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 207s 104ms/step - loss: 0.4796 - accuracy: 0.8181 - val_loss: 0.4841 - val_accuracy: 0.8365
# Epoch 395/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4887 - accuracy: 0.8071
# Epoch 395: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 206s 103ms/step - loss: 0.4887 - accuracy: 0.8071 - val_loss: 0.4722 - val_accuracy: 0.8290
# Epoch 396/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4977 - accuracy: 0.8049
# Epoch 396: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 208s 104ms/step - loss: 0.4977 - accuracy: 0.8049 - val_loss: 0.5328 - val_accuracy: 0.8055
# Epoch 397/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4942 - accuracy: 0.8115
# Epoch 397: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 207s 104ms/step - loss: 0.4942 - accuracy: 0.8115 - val_loss: 0.4230 - val_accuracy: 0.8490
# Epoch 398/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4989 - accuracy: 0.8036
# Epoch 398: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 208s 104ms/step - loss: 0.4989 - accuracy: 0.8036 - val_loss: 0.5622 - val_accuracy: 0.7755
# Epoch 399/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4876 - accuracy: 0.8188
# Epoch 399: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 210s 105ms/step - loss: 0.4876 - accuracy: 0.8188 - val_loss: 0.5804 - val_accuracy: 0.8205
# Epoch 400/400
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4818 - accuracy: 0.8163
# Epoch 400: val_accuracy did not improve from 0.85000
# 2000/2000 [==============================] - 204s 102ms/step - loss: 0.4818 - accuracy: 0.8163 - val_loss: 0.4861 - val_accuracy: 0.8180
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Time Model_XU_Net_strategy_04S-UNIWARD = 83912.21176457405 [seconds]

# %% [markdown]
# ## Test

# %%
model= Xu_Net_strategy() 
PATH_trained_models = "D:\modelos\Model_XU_Net_04S-UNIWARD_1728342103.1582682\saved-model.hdf5"
Final_Results_Test(model,PATH_trained_models)
# Out:
# using 2 classes
# Xunet
#
#
# Best
# D:\modelos\Model_XU_Net_04S-UNIWARD_1728342103.1582682\saved-model.hdf5
# Loss=0.7837 y Accuracy=0.7031
