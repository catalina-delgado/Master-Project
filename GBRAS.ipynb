# %% [markdown]
# # MODELS Net

# %% [markdown]
# ## Libraries

# %%
import numpy
import numpy as np
import random
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from keras.layers import Activation
import tensorflow as tf
import cv2
from tensorflow.keras.layers import Lambda, Layer, ReLU
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, LSTM, SpatialDropout2D, Concatenate
tf.keras.layers.Concatenate()
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, UpSampling2D, BatchNormalization
from keras.layers.core import Reshape
from keras import optimizers
from tensorflow.keras import regularizers
from keras import Input, Model
from time import time
import time as tm
from keras.initializers import Constant, RandomNormal, glorot_normal
from tensorflow.keras.models import load_model
from tensorflow.keras.regularizers import l2
from keras import backend as K
from tensorflow.keras.utils import plot_model
from keras.layers import  concatenate

from tfkan.layers import DenseKAN
from tfkan.layers import Conv2DKAN
from tfkan.layers import base

# %% [markdown]
# ## 30 SRM filters for preprocessing and the activation function

# %%
################################################## 30 SRM FILTERS
srm_weights = np.load('SRM_Kernels.npy') 
biasSRM=numpy.ones(30)
print (srm_weights.shape)
################################################## TLU ACTIVATION FUNCTION
T3 = 3;
def Tanh3(x):
    tanh3 = K.tanh(x)*T3
    return tanh3
##################################################
def thtanh(x,t):
    th=K.tanh(x)*t
    return th
# Out:
# (5, 5, 1, 30)

# %% [markdown]
# ## Gbras-Net architecture

# %%
def GBRAS_Net():
    tf.keras.backend.clear_session()
    #Inputs
    inputs = tf.keras.Input(shape=(256,256,1), name="input_1")
    #Layer 1
    layers = tf.keras.layers.Conv2D(30, (5,5), weights=[srm_weights,biasSRM], strides=(1,1), padding='same', trainable=False, activation=Tanh3, use_bias=True)(inputs)
    layers1 = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=False, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    
    #Layer 2
    layers = tf.keras.layers.DepthwiseConv2D(kernel_size=(1, 1), strides=(1, 1), padding="same", activation="leaky_relu")(layers1)
    layers = tf.keras.layers.SeparableConv2D(30,(3,3), strides=(1,1), padding='same', activation="elu",depth_multiplier=3)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=False, trainable=True)(layers)
    #Layer 3
    layers = tf.keras.layers.DepthwiseConv2D(kernel_size=(1, 1), strides=(1, 1), padding="same", activation="leaky_relu")(layers)
    layers = tf.keras.layers.SeparableConv2D(30,(3,3), padding='same', activation="leaky_relu",depth_multiplier=3)(layers)
    layers2 = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=False, trainable=True)(layers)
    skip1 =   tf.keras.layers.Add()([layers1, layers2])
    #Layer 4
    layers = tf.keras.layers.Conv2D(60, (3,3), strides=(1,1), activation="leaky_relu", padding='same', kernel_initializer='glorot_uniform')(skip1)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=False, trainable=True)(layers)
    # layer 5
    layers = tf.keras.layers.AveragePooling2D((2,2), strides= (2,2))(layers)
    #Layer 5
    layers = tf.keras.layers.Conv2D(60, (3,3), strides=(1,1), activation="leaky_relu", padding='same', kernel_initializer='glorot_uniform')(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=False, trainable=True)(layers)
    #Layer 6
    layers = tf.keras.layers.AveragePooling2D((2,2), strides= (2,2))(layers)
    #Layer 8
    layers = tf.keras.layers.DepthwiseConv2D(kernel_size=(1, 1), strides=(1, 1), padding="same", activation="leaky_relu")(layers)
    layers = tf.keras.layers.SeparableConv2D(60,(3,3), padding='same', activation="elu",depth_multiplier=3)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=False, trainable=True)(layers)
    #Layer 9
    layers = tf.keras.layers.DepthwiseConv2D(kernel_size=(1, 1), strides=(1, 1), padding="same", activation="leaky_relu")(layers)
    layers = tf.keras.layers.SeparableConv2D(30,(3,3), padding='same', activation="leaky_relu",depth_multiplier=3)(layers)
    layers3 = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=False, trainable=True)(layers)
    
    layers = tf.keras.layers.Conv2D(30, (3,3), strides=(1,1), activation="leaky_relu", padding='same', kernel_initializer='glorot_uniform')(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=False, trainable=True)(layers)
    
    layers = tf.keras.layers.Conv2D(30, (3,3), strides=(1,1), activation="leaky_relu", padding='same', kernel_initializer='glorot_uniform')(layers)
    layers4 = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=False, trainable=True)(layers)
    
    skip2 =   tf.keras.layers.Add()([layers3, layers4])
    #Layer 10
    layers = tf.keras.layers.Conv2D(30, (3,3), strides=(1,1), activation="leaky_relu", padding='same', kernel_initializer='glorot_uniform')(skip2)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=False, trainable=True)(layers)
    #Layer 11
    layers = tf.keras.layers.AveragePooling2D((2,2), strides= (2,2))(layers)
    #Layer 12
    layers = tf.keras.layers.Conv2D(30, (3,3), strides=(1,1), activation="leaky_relu", padding='same', kernel_initializer='glorot_uniform')(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=False, trainable=True)(layers)
    #Layer 14
    layers = tf.keras.layers.Conv2D(60, (3,3), strides=(1,1), activation="elu", padding='same', kernel_initializer='glorot_uniform')(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=False, trainable=True)(layers)
    #Layer 15
    layers = tf.keras.layers.GlobalAveragePooling2D(data_format="channels_last")(layers)
    #FC
    layers = tf.keras.layers.Dense(128,kernel_initializer='glorot_normal',kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers)
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Dense(64,kernel_initializer='glorot_normal',kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers)
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Dense(32,kernel_initializer='glorot_normal',kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers)
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)

    #Layer 18
    layers = DenseKAN(2)(layers)
    #Layer 19
    predictions = tf.keras.layers.Softmax(axis=1)(layers)
    #Model generation
    model = tf.keras.Model(inputs = inputs, outputs=predictions)
    #Optimizer
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    print ("Model GBRAS-Net Generated")
    #Model compilation
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# ## Defining different functions to work with the architecture

# %%
def train(model, X_train, y_train, X_valid, y_valid, X_test, y_test, batch_size, epochs, initial_epoch = 0, model_name="", num_test=""):
    start_time = tm.time()
    log_dir="D:/testing_"+num_test+"/"+model_name+"_"+"{}".format(time())
    tensorboard = tf.keras.callbacks.TensorBoard(log_dir)
    filepath = log_dir+"/saved-model.hdf5"
    checkpoint = tf.keras.callbacks.ModelCheckpoint(
        filepath, 
        monitor='val_accuracy', 
        save_best_only=True, 
        mode='max',
        verbose=1
    )
    model.reset_states()
    history=model.fit(X_train, y_train, epochs=epochs, 
                        callbacks=[tensorboard,  checkpoint], 
                        batch_size=batch_size,
                        validation_data=(X_valid, y_valid),
                        initial_epoch=initial_epoch)
    
    metrics = model.evaluate(X_test, y_test, verbose=0)
    results_dir="D:/testing_"+num_test+"/"+model_name+"/"
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
      
        plt.figure(figsize=(10, 10))
        #plt.subplot(1,2,1)
        #Plot training & validation accuracy values
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('Accuracy Vs Epochs')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.grid('on')
        plt.savefig(results_dir+'Accuracy_Xu_Net_'+model_name+'.eps', format='eps')
        plt.savefig(results_dir+'Accuracy_Xu_Net_'+model_name+'.svg', format='svg')
        plt.savefig(results_dir+'Accuracy_Xu_Net_'+model_name+'.pdf', format='pdf')
        plt.show()
        
        plt.figure(figsize=(10, 10))
        #plt.subplot(1,2,2)
        #Plot training & validation loss values
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('Loss Vs Epochs')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.grid('on')
        plt.savefig(results_dir+'Loss_Xu_Net_'+model_name+'.eps', format='eps')
        plt.savefig(results_dir+'Loss_Xu_Net_'+model_name+'.svg', format='svg')
        plt.savefig(results_dir+'Loss_Xu_Net_'+model_name+'.pdf', format='pdf')
        plt.show()

    TIME = tm.time() - start_time
    print("Time "+model_name+" = %s [seconds]" % TIME)
    return {k:v for k,v in zip (model.metrics_names, metrics)}

# %%
def Final_Results_Test(model,PATH_trained_models):
    B_accuracy = 0 #B --> Best
    for filename in os.listdir(PATH_trained_models):
        if filename != ('train') and filename != ('validation'):
            print(filename)
            model.load_weights(PATH_trained_models+'/'+filename)
            loss,accuracy = model.evaluate(X_test, y_test,verbose=0)
            print(f'Loss={loss:.4f} y Accuracy={accuracy:0.4f}'+'\n') 
            if accuracy > B_accuracy:
                B_accuracy = accuracy
                B_loss = loss
                B_name = filename
    print("\n\nBest")
    print(B_name)
    print(f'Loss={B_loss:.4f} y Accuracy={B_accuracy:0.4f}'+'\n')

# %%
from tqdm import tqdm
def plot_train_valid(model,PATH_trained_models,model_name):
    acc_train=[]
    acc_valid=[]
    loss_train=[]
    loss_valid=[]
    for filename in tqdm(os.listdir(PATH_trained_models)):
        if filename != ('train') and filename != ('validation'):
            print(filename)
            model.load_weights(PATH_trained_models+'/'+filename)
            loss,accuracy = model.evaluate(X_train, y_train,verbose=0)
            acc_train.append(accuracy)
            loss_train.append(loss)
            loss,accuracy = model.evaluate(X_valid, y_valid,verbose=0)
            acc_valid.append(accuracy)
            loss_valid.append(loss)

    results_dir="D:/modelos/"+model_name+"/"
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)

   
        plt.figure(figsize=(10, 10))
        #plt.subplot(1,2,1)
        #Plot training & validation accuracy values
        plt.plot(acc_train)
        plt.plot(acc_valid)
        plt.title('Accuracy Vs Epochs')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.grid('on')
        plt.savefig(results_dir+'Accuracy_Xu_Net_'+model_name+'.eps', format='eps')
        plt.savefig(results_dir+'Accuracy_Xu_Net_'+model_name+'.svg', format='svg')
        plt.savefig(results_dir+'Accuracy_Xu_Net_'+model_name+'.pdf', format='pdf')
        plt.show()

        plt.figure(figsize=(10, 10))
        #plt.subplot(1,2,2)
        #Plot training & validation loss values
        plt.plot(loss_train)
        plt.plot(loss_valid)
        plt.title('Loss Vs Epochs')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.grid('on')
        plt.savefig(results_dir+'Loss_Xu_Net_'+model_name+'.eps', format='eps')
        plt.savefig(results_dir+'Loss_Xu_Net_'+model_name+'.svg', format='svg')
        plt.savefig(results_dir+'Loss_Xu_Net_'+model_name+'.pdf', format='pdf')
        plt.show()

        '''
        plt.figure(figsize=(10, 10))
        #plt.subplot(1,2,2)
        #Plot training & validation loss values
        plt.plot(history.history['lr'])
        plt.ylabel('Lr')
        plt.xlabel('Epoch')
        plt.grid('on')
        plt.show()
        '''
    results={'acc_train':acc_train,'acc_valid':acc_valid,'loss_train':loss_train,'loss_valid':loss_valid}
    return results

# %% [markdown]
# ## Plot ROC curves

# %%
from sklearn.metrics import (
    average_precision_score,
    precision_recall_curve,
    roc_auc_score,
    roc_curve,
)

def get_curve(gt, pred, target_names,model_name):
    labels=[]
    for i in range(len(target_names)):
        
        curve_function = roc_curve
        auc_roc = roc_auc_score(gt[:, i], pred[:, i])
        label = model_name+target_names[i] + " AUC: %.3f " % auc_roc
        labels.append(label)
        xlabel = "False positive rate"
        ylabel = "True positive rate"
        a, b, _ = curve_function(gt[:, i], pred[:, i])
        plt.figure(1, figsize=(7, 7))
        plt.plot([0, 1], [0, 1], 'k--')
        plt.plot(a, b, label=label)
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)

        plt.legend(loc='upper center', bbox_to_anchor=(1.3, 1),
                  fancybox=True, ncol=1)
      
    return [a,b],labels
labels = ["Cover","Stego"]

# %% [markdown]
# ## Working with BOSSbase 1.01 WOW y PAYLOAD = 0.4bpp

# %% [markdown]
# In the README, there is a link to download the databases we use for the work. There are two databases BOSSbase 1.01 and Bows2+ BOSSbase 1.01, cover images and stego. You can choose the payload of 0.2 and 0.4 bpp for each of the databases.

# %%
#Train
X_train = np.load('data_load/X_train.npy')
y_train = np.load('data_load/y_train.npy')
#Valid
X_valid = np.load('data_load/X_valid.npy')
y_valid = np.load('data_load/y_valid.npy')
#Test
X_test = np.load('data_load/X_test.npy')
y_test = np.load('data_load/y_test.npy')

print(X_train.shape)
print(y_train.shape)
print(X_valid.shape)
print(y_valid.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (8000, 256, 256, 1)
# (8000, 2)
# (2000, 256, 256, 1)
# (2000, 2)
# (10000, 256, 256, 1)
# (10000, 2)

# %% [markdown]
# ## CNN name and algorithm

# %%
base_name="04S-UNIWARD"

# %%
model= GBRAS_Net() 
model.summary()
# Out:
# Model GBRAS-Net Generated
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 30  780         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 30  90         ['conv2d[0][0]']
#  alization)                     )
#
#  depthwise_conv2d (DepthwiseCon  (None, 256, 256, 30  60         ['batch_normalization[0][0]']
#  v2D)                           )
#
#  separable_conv2d (SeparableCon  (None, 256, 256, 30  3540       ['depthwise_conv2d[0][0]']
#  v2D)                           )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 30  90         ['separable_conv2d[0][0]']
#  rmalization)                   )
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 256, 256, 30  60         ['batch_normalization_1[0][0]']
#  onv2D)                         )
#
#  separable_conv2d_1 (SeparableC  (None, 256, 256, 30  3540       ['depthwise_conv2d_1[0][0]']
#  onv2D)                         )
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 30  90         ['separable_conv2d_1[0][0]']
#  rmalization)                   )
#
#  add (Add)                      (None, 256, 256, 30  0           ['batch_normalization[0][0]',
#                                 )                                 'batch_normalization_2[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 60  16260       ['add[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 60  180        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  average_pooling2d (AveragePool  (None, 128, 128, 60  0          ['batch_normalization_3[0][0]']
#  ing2D)                         )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 60  32460       ['average_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 60  180        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  average_pooling2d_1 (AveragePo  (None, 64, 64, 60)  0           ['batch_normalization_4[0][0]']
#  oling2D)
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 64, 64, 60)  120         ['average_pooling2d_1[0][0]']
#  onv2D)
#
#  separable_conv2d_2 (SeparableC  (None, 64, 64, 60)  12480       ['depthwise_conv2d_2[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 60)  180         ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 64, 64, 60)  120         ['batch_normalization_5[0][0]']
#  onv2D)
#
#  separable_conv2d_3 (SeparableC  (None, 64, 64, 30)  7050        ['depthwise_conv2d_3[0][0]']
#  onv2D)
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 30)   8130        ['separable_conv2d_3[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 30)  90          ['conv2d_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 30)   8130        ['batch_normalization_7[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 30)  90          ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 30)  90          ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 64, 64, 30)   0           ['batch_normalization_6[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 30)   8130        ['add_1[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 30)  90          ['conv2d_5[0][0]']
#  rmalization)
#
#  average_pooling2d_2 (AveragePo  (None, 32, 32, 30)  0           ['batch_normalization_9[0][0]']
#  oling2D)
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 30)   8130        ['average_pooling2d_2[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 30)  90          ['conv2d_6[0][0]']
#  ormalization)
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 60)   16260       ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 60)  180         ['conv2d_7[0][0]']
#  ormalization)
#
#  global_average_pooling2d (Glob  (None, 60)          0           ['batch_normalization_11[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 128)          7808        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  re_lu (ReLU)                   (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['re_lu[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 64)           0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['re_lu_1[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 32)           0           ['dense_2[0][0]']
#
#  dense_kan (DenseKAN)           (None, 2)            962         ['re_lu_2[0][0]']
#
#  softmax (Softmax)              (None, 2)            0           ['dense_kan[0][0]']
#
# ==================================================================================================
# Total params: 145,796
# Trainable params: 143,672
# Non-trainable params: 2,124
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training gbras-net

# %%
name="Model_"+'GBRAS_net'+"_"+base_name
_, history  = train(model, X_train, y_train, X_valid, y_valid, X_test, y_test, batch_size=32, epochs=100, model_name=name, num_test='4_GBRAS_MOD')
# Out:
# Epoch 1/100
# 250/250 [==============================] - ETA: 0s - loss: 0.7088 - accuracy: 0.5246
# Epoch 1: val_accuracy improved from -inf to 0.52950, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 66s 263ms/step - loss: 0.7088 - accuracy: 0.5246 - val_loss: 0.7794 - val_accuracy: 0.5295
# Epoch 2/100
# 250/250 [==============================] - ETA: 0s - loss: 0.6783 - accuracy: 0.5761
# Epoch 2: val_accuracy improved from 0.52950 to 0.55250, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 63s 253ms/step - loss: 0.6783 - accuracy: 0.5761 - val_loss: 0.7729 - val_accuracy: 0.5525
# Epoch 3/100
# 250/250 [==============================] - ETA: 0s - loss: 0.6235 - accuracy: 0.6237
# Epoch 3: val_accuracy improved from 0.55250 to 0.61800, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 62s 246ms/step - loss: 0.6235 - accuracy: 0.6237 - val_loss: 0.6210 - val_accuracy: 0.6180
# Epoch 4/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5991 - accuracy: 0.6414
# Epoch 4: val_accuracy improved from 0.61800 to 0.65650, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 62s 247ms/step - loss: 0.5991 - accuracy: 0.6414 - val_loss: 0.5835 - val_accuracy: 0.6565
# Epoch 5/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5727 - accuracy: 0.6562
# Epoch 5: val_accuracy improved from 0.65650 to 0.68100, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 62s 247ms/step - loss: 0.5727 - accuracy: 0.6562 - val_loss: 0.5574 - val_accuracy: 0.6810
# Epoch 6/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5730 - accuracy: 0.6618
# Epoch 6: val_accuracy improved from 0.68100 to 0.68600, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 62s 247ms/step - loss: 0.5730 - accuracy: 0.6618 - val_loss: 0.5342 - val_accuracy: 0.6860
# Epoch 7/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5607 - accuracy: 0.6631
# Epoch 7: val_accuracy improved from 0.68600 to 0.69650, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 62s 247ms/step - loss: 0.5607 - accuracy: 0.6631 - val_loss: 0.5286 - val_accuracy: 0.6965
# Epoch 8/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5595 - accuracy: 0.6720
# Epoch 8: val_accuracy did not improve from 0.69650
# 250/250 [==============================] - 62s 246ms/step - loss: 0.5595 - accuracy: 0.6720 - val_loss: 0.5400 - val_accuracy: 0.6790
# Epoch 9/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5507 - accuracy: 0.6775
# Epoch 9: val_accuracy did not improve from 0.69650
# 250/250 [==============================] - 62s 247ms/step - loss: 0.5507 - accuracy: 0.6775 - val_loss: 0.6334 - val_accuracy: 0.6090
# Epoch 10/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5399 - accuracy: 0.6783
# Epoch 10: val_accuracy did not improve from 0.69650
# 250/250 [==============================] - 62s 247ms/step - loss: 0.5399 - accuracy: 0.6783 - val_loss: 0.5359 - val_accuracy: 0.6815
# Epoch 11/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5427 - accuracy: 0.6826
# Epoch 11: val_accuracy did not improve from 0.69650
# 250/250 [==============================] - 62s 246ms/step - loss: 0.5427 - accuracy: 0.6826 - val_loss: 0.5531 - val_accuracy: 0.6715
# Epoch 12/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5357 - accuracy: 0.6899
# Epoch 12: val_accuracy improved from 0.69650 to 0.70300, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 62s 247ms/step - loss: 0.5357 - accuracy: 0.6899 - val_loss: 0.5183 - val_accuracy: 0.7030
# Epoch 13/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5320 - accuracy: 0.6881
# Epoch 13: val_accuracy did not improve from 0.70300
# 250/250 [==============================] - 62s 247ms/step - loss: 0.5320 - accuracy: 0.6881 - val_loss: 0.5162 - val_accuracy: 0.7015
# Epoch 14/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5295 - accuracy: 0.6925
# Epoch 14: val_accuracy did not improve from 0.70300
# 250/250 [==============================] - 62s 247ms/step - loss: 0.5295 - accuracy: 0.6925 - val_loss: 0.5148 - val_accuracy: 0.7020
# Epoch 15/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5326 - accuracy: 0.6855
# Epoch 15: val_accuracy improved from 0.70300 to 0.70850, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 62s 248ms/step - loss: 0.5326 - accuracy: 0.6855 - val_loss: 0.5048 - val_accuracy: 0.7085
# Epoch 16/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5301 - accuracy: 0.6965
# Epoch 16: val_accuracy did not improve from 0.70850
# 250/250 [==============================] - 62s 247ms/step - loss: 0.5301 - accuracy: 0.6965 - val_loss: 0.5342 - val_accuracy: 0.6860
# Epoch 17/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5168 - accuracy: 0.7003
# Epoch 17: val_accuracy did not improve from 0.70850
# 250/250 [==============================] - 63s 252ms/step - loss: 0.5168 - accuracy: 0.7003 - val_loss: 0.5293 - val_accuracy: 0.6880
# Epoch 18/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5150 - accuracy: 0.7042
# Epoch 18: val_accuracy improved from 0.70850 to 0.71150, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 64s 256ms/step - loss: 0.5150 - accuracy: 0.7042 - val_loss: 0.5017 - val_accuracy: 0.7115
# Epoch 19/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5132 - accuracy: 0.7054
# Epoch 19: val_accuracy did not improve from 0.71150
# 250/250 [==============================] - 64s 254ms/step - loss: 0.5132 - accuracy: 0.7054 - val_loss: 0.5245 - val_accuracy: 0.7040
# Epoch 20/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5031 - accuracy: 0.7089
# Epoch 20: val_accuracy did not improve from 0.71150
# 250/250 [==============================] - 64s 255ms/step - loss: 0.5031 - accuracy: 0.7089 - val_loss: 0.5463 - val_accuracy: 0.6830
# Epoch 21/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5137 - accuracy: 0.6981
# Epoch 21: val_accuracy did not improve from 0.71150
# 250/250 [==============================] - 64s 255ms/step - loss: 0.5137 - accuracy: 0.6981 - val_loss: 0.5102 - val_accuracy: 0.7025
# Epoch 22/100
# 250/250 [==============================] - ETA: 0s - loss: 0.5046 - accuracy: 0.7156
# Epoch 22: val_accuracy did not improve from 0.71150
# 250/250 [==============================] - 64s 255ms/step - loss: 0.5046 - accuracy: 0.7156 - val_loss: 0.5354 - val_accuracy: 0.6990
# Epoch 23/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4982 - accuracy: 0.7156
# Epoch 23: val_accuracy improved from 0.71150 to 0.71850, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 64s 255ms/step - loss: 0.4982 - accuracy: 0.7156 - val_loss: 0.5117 - val_accuracy: 0.7185
# Epoch 24/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4981 - accuracy: 0.7182
# Epoch 24: val_accuracy improved from 0.71850 to 0.73750, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 64s 255ms/step - loss: 0.4981 - accuracy: 0.7182 - val_loss: 0.4752 - val_accuracy: 0.7375
# Epoch 25/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4857 - accuracy: 0.7258
# Epoch 25: val_accuracy did not improve from 0.73750
# 250/250 [==============================] - 64s 254ms/step - loss: 0.4857 - accuracy: 0.7258 - val_loss: 0.4845 - val_accuracy: 0.7175
# Epoch 26/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4953 - accuracy: 0.7188
# Epoch 26: val_accuracy did not improve from 0.73750
# 250/250 [==============================] - 63s 253ms/step - loss: 0.4953 - accuracy: 0.7188 - val_loss: 0.4656 - val_accuracy: 0.7340
# Epoch 27/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4860 - accuracy: 0.7271
# Epoch 27: val_accuracy improved from 0.73750 to 0.73900, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 64s 255ms/step - loss: 0.4860 - accuracy: 0.7271 - val_loss: 0.4646 - val_accuracy: 0.7390
# Epoch 28/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4817 - accuracy: 0.7290
# Epoch 28: val_accuracy did not improve from 0.73900
# 250/250 [==============================] - 63s 254ms/step - loss: 0.4817 - accuracy: 0.7290 - val_loss: 0.5010 - val_accuracy: 0.7175
# Epoch 29/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4797 - accuracy: 0.7318
# Epoch 29: val_accuracy did not improve from 0.73900
# 250/250 [==============================] - 64s 254ms/step - loss: 0.4797 - accuracy: 0.7318 - val_loss: 0.4668 - val_accuracy: 0.7365
# Epoch 30/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4783 - accuracy: 0.7311
# Epoch 30: val_accuracy did not improve from 0.73900
# 250/250 [==============================] - 64s 254ms/step - loss: 0.4783 - accuracy: 0.7311 - val_loss: 0.5373 - val_accuracy: 0.7045
# Epoch 31/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4682 - accuracy: 0.7369
# Epoch 31: val_accuracy did not improve from 0.73900
# 250/250 [==============================] - 64s 255ms/step - loss: 0.4682 - accuracy: 0.7369 - val_loss: 0.5124 - val_accuracy: 0.7065
# Epoch 32/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.7368
# Epoch 32: val_accuracy improved from 0.73900 to 0.74050, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 64s 255ms/step - loss: 0.4661 - accuracy: 0.7368 - val_loss: 0.4601 - val_accuracy: 0.7405
# Epoch 33/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4611 - accuracy: 0.7469
# Epoch 33: val_accuracy did not improve from 0.74050
# 250/250 [==============================] - 64s 254ms/step - loss: 0.4611 - accuracy: 0.7469 - val_loss: 0.6009 - val_accuracy: 0.6685
# Epoch 34/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4614 - accuracy: 0.7416
# Epoch 34: val_accuracy improved from 0.74050 to 0.76150, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 64s 255ms/step - loss: 0.4614 - accuracy: 0.7416 - val_loss: 0.4486 - val_accuracy: 0.7615
# Epoch 35/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4440 - accuracy: 0.7523
# Epoch 35: val_accuracy did not improve from 0.76150
# 250/250 [==============================] - 63s 254ms/step - loss: 0.4440 - accuracy: 0.7523 - val_loss: 0.4639 - val_accuracy: 0.7570
# Epoch 36/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4423 - accuracy: 0.7515
# Epoch 36: val_accuracy did not improve from 0.76150
# 250/250 [==============================] - 64s 254ms/step - loss: 0.4423 - accuracy: 0.7515 - val_loss: 0.4528 - val_accuracy: 0.7445
# Epoch 37/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4358 - accuracy: 0.7585
# Epoch 37: val_accuracy did not improve from 0.76150
# 250/250 [==============================] - 64s 254ms/step - loss: 0.4358 - accuracy: 0.7585 - val_loss: 0.4290 - val_accuracy: 0.7610
# Epoch 38/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4379 - accuracy: 0.7665
# Epoch 38: val_accuracy did not improve from 0.76150
# 250/250 [==============================] - 64s 254ms/step - loss: 0.4379 - accuracy: 0.7665 - val_loss: 0.4512 - val_accuracy: 0.7595
# Epoch 39/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4313 - accuracy: 0.7638
# Epoch 39: val_accuracy improved from 0.76150 to 0.76500, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 64s 254ms/step - loss: 0.4313 - accuracy: 0.7638 - val_loss: 0.4261 - val_accuracy: 0.7650
# Epoch 40/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4255 - accuracy: 0.7667
# Epoch 40: val_accuracy improved from 0.76500 to 0.78050, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 64s 255ms/step - loss: 0.4255 - accuracy: 0.7667 - val_loss: 0.4083 - val_accuracy: 0.7805
# Epoch 41/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4257 - accuracy: 0.7664
# Epoch 41: val_accuracy did not improve from 0.78050
# 250/250 [==============================] - 64s 254ms/step - loss: 0.4257 - accuracy: 0.7664 - val_loss: 0.4873 - val_accuracy: 0.7560
# Epoch 42/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4119 - accuracy: 0.7789
# Epoch 42: val_accuracy did not improve from 0.78050
# 250/250 [==============================] - 64s 254ms/step - loss: 0.4119 - accuracy: 0.7789 - val_loss: 0.4507 - val_accuracy: 0.7560
# Epoch 43/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4087 - accuracy: 0.7785
# Epoch 43: val_accuracy did not improve from 0.78050
# 250/250 [==============================] - 63s 253ms/step - loss: 0.4087 - accuracy: 0.7785 - val_loss: 0.4408 - val_accuracy: 0.7630
# Epoch 44/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4072 - accuracy: 0.7816
# Epoch 44: val_accuracy did not improve from 0.78050
# 250/250 [==============================] - 63s 253ms/step - loss: 0.4072 - accuracy: 0.7816 - val_loss: 0.4502 - val_accuracy: 0.7535
# Epoch 45/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3955 - accuracy: 0.7859
# Epoch 45: val_accuracy did not improve from 0.78050
# 250/250 [==============================] - 63s 253ms/step - loss: 0.3955 - accuracy: 0.7859 - val_loss: 0.5614 - val_accuracy: 0.7150
# Epoch 46/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3939 - accuracy: 0.7884
# Epoch 46: val_accuracy improved from 0.78050 to 0.78250, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 63s 254ms/step - loss: 0.3939 - accuracy: 0.7884 - val_loss: 0.4096 - val_accuracy: 0.7825
# Epoch 47/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3930 - accuracy: 0.7866
# Epoch 47: val_accuracy improved from 0.78250 to 0.78400, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 63s 254ms/step - loss: 0.3930 - accuracy: 0.7866 - val_loss: 0.4359 - val_accuracy: 0.7840
# Epoch 48/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3921 - accuracy: 0.7891
# Epoch 48: val_accuracy did not improve from 0.78400
# 250/250 [==============================] - 63s 253ms/step - loss: 0.3921 - accuracy: 0.7891 - val_loss: 0.7671 - val_accuracy: 0.6780
# Epoch 49/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3729 - accuracy: 0.8016
# Epoch 49: val_accuracy improved from 0.78400 to 0.79100, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 63s 254ms/step - loss: 0.3729 - accuracy: 0.8016 - val_loss: 0.4393 - val_accuracy: 0.7910
# Epoch 50/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3716 - accuracy: 0.8060
# Epoch 50: val_accuracy did not improve from 0.79100
# 250/250 [==============================] - 63s 253ms/step - loss: 0.3716 - accuracy: 0.8060 - val_loss: 0.4392 - val_accuracy: 0.7725
# Epoch 51/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3718 - accuracy: 0.8024
# Epoch 51: val_accuracy did not improve from 0.79100
# 250/250 [==============================] - 63s 253ms/step - loss: 0.3718 - accuracy: 0.8024 - val_loss: 0.4285 - val_accuracy: 0.7860
# Epoch 52/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3667 - accuracy: 0.8051
# Epoch 52: val_accuracy did not improve from 0.79100
# 250/250 [==============================] - 63s 253ms/step - loss: 0.3667 - accuracy: 0.8051 - val_loss: 0.4132 - val_accuracy: 0.7885
# Epoch 53/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3558 - accuracy: 0.8067
# Epoch 53: val_accuracy did not improve from 0.79100
# 250/250 [==============================] - 63s 253ms/step - loss: 0.3558 - accuracy: 0.8067 - val_loss: 0.4138 - val_accuracy: 0.7910
# Epoch 54/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3577 - accuracy: 0.8086
# Epoch 54: val_accuracy did not improve from 0.79100
# 250/250 [==============================] - 63s 253ms/step - loss: 0.3577 - accuracy: 0.8086 - val_loss: 0.4145 - val_accuracy: 0.7910
# Epoch 55/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3655 - accuracy: 0.8075
# Epoch 55: val_accuracy improved from 0.79100 to 0.79950, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 64s 254ms/step - loss: 0.3655 - accuracy: 0.8075 - val_loss: 0.4155 - val_accuracy: 0.7995
# Epoch 56/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3543 - accuracy: 0.8083
# Epoch 56: val_accuracy did not improve from 0.79950
# 250/250 [==============================] - 63s 253ms/step - loss: 0.3543 - accuracy: 0.8083 - val_loss: 0.4123 - val_accuracy: 0.7880
# Epoch 57/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3451 - accuracy: 0.8224
# Epoch 57: val_accuracy did not improve from 0.79950
# 250/250 [==============================] - 63s 254ms/step - loss: 0.3451 - accuracy: 0.8224 - val_loss: 0.4363 - val_accuracy: 0.7910
# Epoch 58/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3383 - accuracy: 0.8230
# Epoch 58: val_accuracy did not improve from 0.79950
# 250/250 [==============================] - 63s 253ms/step - loss: 0.3383 - accuracy: 0.8230 - val_loss: 0.4560 - val_accuracy: 0.7765
# Epoch 59/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3418 - accuracy: 0.8230
# Epoch 59: val_accuracy did not improve from 0.79950
# 250/250 [==============================] - 64s 254ms/step - loss: 0.3418 - accuracy: 0.8230 - val_loss: 0.4705 - val_accuracy: 0.7745
# Epoch 60/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3366 - accuracy: 0.8224
# Epoch 60: val_accuracy did not improve from 0.79950
# 250/250 [==============================] - 63s 253ms/step - loss: 0.3366 - accuracy: 0.8224 - val_loss: 0.4530 - val_accuracy: 0.7790
# Epoch 61/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3192 - accuracy: 0.8321
# Epoch 61: val_accuracy improved from 0.79950 to 0.80600, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 63s 254ms/step - loss: 0.3192 - accuracy: 0.8321 - val_loss: 0.4037 - val_accuracy: 0.8060
# Epoch 62/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3127 - accuracy: 0.8378
# Epoch 62: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 253ms/step - loss: 0.3127 - accuracy: 0.8378 - val_loss: 0.4358 - val_accuracy: 0.7825
# Epoch 63/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3156 - accuracy: 0.8363
# Epoch 63: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 253ms/step - loss: 0.3156 - accuracy: 0.8363 - val_loss: 0.4678 - val_accuracy: 0.7945
# Epoch 64/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3189 - accuracy: 0.8332
# Epoch 64: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 253ms/step - loss: 0.3189 - accuracy: 0.8332 - val_loss: 0.4510 - val_accuracy: 0.7940
# Epoch 65/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3178 - accuracy: 0.8350
# Epoch 65: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.3178 - accuracy: 0.8350 - val_loss: 0.4558 - val_accuracy: 0.7940
# Epoch 66/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3086 - accuracy: 0.8413
# Epoch 66: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 64s 254ms/step - loss: 0.3086 - accuracy: 0.8413 - val_loss: 0.4712 - val_accuracy: 0.8010
# Epoch 67/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3136 - accuracy: 0.8335
# Epoch 67: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.3136 - accuracy: 0.8335 - val_loss: 0.4554 - val_accuracy: 0.7945
# Epoch 68/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2959 - accuracy: 0.8455
# Epoch 68: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 64s 254ms/step - loss: 0.2959 - accuracy: 0.8455 - val_loss: 0.4539 - val_accuracy: 0.7915
# Epoch 69/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2842 - accuracy: 0.8536
# Epoch 69: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2842 - accuracy: 0.8536 - val_loss: 0.5546 - val_accuracy: 0.7545
# Epoch 70/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3058 - accuracy: 0.8375
# Epoch 70: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.3058 - accuracy: 0.8375 - val_loss: 0.4981 - val_accuracy: 0.7795
# Epoch 71/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2869 - accuracy: 0.8459
# Epoch 71: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2869 - accuracy: 0.8459 - val_loss: 0.4897 - val_accuracy: 0.7920
# Epoch 72/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2896 - accuracy: 0.8480
# Epoch 72: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2896 - accuracy: 0.8480 - val_loss: 0.4543 - val_accuracy: 0.8035
# Epoch 73/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2755 - accuracy: 0.8571
# Epoch 73: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2755 - accuracy: 0.8571 - val_loss: 0.5253 - val_accuracy: 0.7960
# Epoch 74/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2790 - accuracy: 0.8586
# Epoch 74: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2790 - accuracy: 0.8586 - val_loss: 0.5506 - val_accuracy: 0.7805
# Epoch 75/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2715 - accuracy: 0.8612
# Epoch 75: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2715 - accuracy: 0.8612 - val_loss: 0.4441 - val_accuracy: 0.7980
# Epoch 76/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2747 - accuracy: 0.8550
# Epoch 76: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2747 - accuracy: 0.8550 - val_loss: 0.5256 - val_accuracy: 0.7825
# Epoch 77/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2653 - accuracy: 0.8624
# Epoch 77: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2653 - accuracy: 0.8624 - val_loss: 0.5502 - val_accuracy: 0.8005
# Epoch 78/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2666 - accuracy: 0.8599
# Epoch 78: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 64s 254ms/step - loss: 0.2666 - accuracy: 0.8599 - val_loss: 0.4963 - val_accuracy: 0.7970
# Epoch 79/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2571 - accuracy: 0.8644
# Epoch 79: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2571 - accuracy: 0.8644 - val_loss: 0.5464 - val_accuracy: 0.7955
# Epoch 80/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2736 - accuracy: 0.8560
# Epoch 80: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 64s 254ms/step - loss: 0.2736 - accuracy: 0.8560 - val_loss: 0.4458 - val_accuracy: 0.8045
# Epoch 81/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2441 - accuracy: 0.8733
# Epoch 81: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2441 - accuracy: 0.8733 - val_loss: 0.5440 - val_accuracy: 0.7905
# Epoch 82/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2502 - accuracy: 0.8683
# Epoch 82: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2502 - accuracy: 0.8683 - val_loss: 0.5893 - val_accuracy: 0.7895
# Epoch 83/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2513 - accuracy: 0.8700
# Epoch 83: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2513 - accuracy: 0.8700 - val_loss: 0.4965 - val_accuracy: 0.7875
# Epoch 84/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2392 - accuracy: 0.8795
# Epoch 84: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2392 - accuracy: 0.8795 - val_loss: 0.5255 - val_accuracy: 0.7935
# Epoch 85/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2398 - accuracy: 0.8749
# Epoch 85: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 64s 254ms/step - loss: 0.2398 - accuracy: 0.8749 - val_loss: 0.5780 - val_accuracy: 0.8055
# Epoch 86/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2478 - accuracy: 0.8723
# Epoch 86: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 64s 254ms/step - loss: 0.2478 - accuracy: 0.8723 - val_loss: 0.5572 - val_accuracy: 0.7790
# Epoch 87/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2325 - accuracy: 0.8811
# Epoch 87: val_accuracy did not improve from 0.80600
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2325 - accuracy: 0.8811 - val_loss: 0.5270 - val_accuracy: 0.7800
# Epoch 88/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2393 - accuracy: 0.8748
# Epoch 88: val_accuracy improved from 0.80600 to 0.80700, saving model to D:/testing_4_GBRAS_MOD/Model_GBRAS_net_04S-UNIWARD_1729057553.8224456\saved-model.hdf5
# 250/250 [==============================] - 64s 254ms/step - loss: 0.2393 - accuracy: 0.8748 - val_loss: 0.5400 - val_accuracy: 0.8070
# Epoch 89/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2322 - accuracy: 0.8831
# Epoch 89: val_accuracy did not improve from 0.80700
# 250/250 [==============================] - 63s 253ms/step - loss: 0.2322 - accuracy: 0.8831 - val_loss: 0.4950 - val_accuracy: 0.7965
# Epoch 90/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2252 - accuracy: 0.8849
# Epoch 90: val_accuracy did not improve from 0.80700
# 250/250 [==============================] - 64s 254ms/step - loss: 0.2252 - accuracy: 0.8849 - val_loss: 0.6815 - val_accuracy: 0.7940
# Epoch 91/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2280 - accuracy: 0.8832
# Epoch 91: val_accuracy did not improve from 0.80700
# 250/250 [==============================] - 63s 253ms/step - loss: 0.2280 - accuracy: 0.8832 - val_loss: 0.5562 - val_accuracy: 0.7900
# Epoch 92/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2265 - accuracy: 0.8826
# Epoch 92: val_accuracy did not improve from 0.80700
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2265 - accuracy: 0.8826 - val_loss: 0.5564 - val_accuracy: 0.7985
# Epoch 93/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2267 - accuracy: 0.8798
# Epoch 93: val_accuracy did not improve from 0.80700
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2267 - accuracy: 0.8798 - val_loss: 0.6017 - val_accuracy: 0.7950
# Epoch 94/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.8871
# Epoch 94: val_accuracy did not improve from 0.80700
# 250/250 [==============================] - 63s 253ms/step - loss: 0.2208 - accuracy: 0.8871 - val_loss: 0.5492 - val_accuracy: 0.7910
# Epoch 95/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2231 - accuracy: 0.8901
# Epoch 95: val_accuracy did not improve from 0.80700
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2231 - accuracy: 0.8901 - val_loss: 0.4921 - val_accuracy: 0.7965
# Epoch 96/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2144 - accuracy: 0.8898
# Epoch 96: val_accuracy did not improve from 0.80700
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2144 - accuracy: 0.8898 - val_loss: 0.5854 - val_accuracy: 0.7965
# Epoch 97/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2259 - accuracy: 0.8879
# Epoch 97: val_accuracy did not improve from 0.80700
# 250/250 [==============================] - 63s 253ms/step - loss: 0.2259 - accuracy: 0.8879 - val_loss: 0.6418 - val_accuracy: 0.7850
# Epoch 98/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2050 - accuracy: 0.8942
# Epoch 98: val_accuracy did not improve from 0.80700
# 250/250 [==============================] - 63s 253ms/step - loss: 0.2050 - accuracy: 0.8942 - val_loss: 0.6074 - val_accuracy: 0.7925
# Epoch 99/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2206 - accuracy: 0.8871
# Epoch 99: val_accuracy did not improve from 0.80700
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2206 - accuracy: 0.8871 - val_loss: 0.6315 - val_accuracy: 0.7905
# Epoch 100/100
# 250/250 [==============================] - ETA: 0s - loss: 0.2104 - accuracy: 0.8913
# Epoch 100: val_accuracy did not improve from 0.80700
# 250/250 [==============================] - 63s 254ms/step - loss: 0.2104 - accuracy: 0.8913 - val_loss: 0.5204 - val_accuracy: 0.8060
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Time Model_GBRAS_net_04S-UNIWARD = 6347.83088183403 [seconds]
