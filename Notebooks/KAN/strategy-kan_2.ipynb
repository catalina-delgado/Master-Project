# %% [markdown]
# # Xu-Net

# %% [markdown]
# ## Libraries

# %%
import numpy
import numpy as np
import random
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from keras.layers import Activation
import tensorflow as tf
import cv2
from tensorflow.keras.layers import Lambda, Layer, ReLU
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, LSTM, SpatialDropout2D, Concatenate
tf.keras.layers.Concatenate()
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, UpSampling2D, BatchNormalization
from keras.layers.core import Reshape
from keras import optimizers
from tensorflow.keras import regularizers
from keras import Input, Model
from time import time
import time as tm
from keras.initializers import Constant, RandomNormal, glorot_normal
from tensorflow.keras.models import load_model
from tensorflow.keras.regularizers import l2
from keras import backend as K
from tensorflow.keras.utils import plot_model
from keras.layers import  concatenate

from tfkan.layers import DenseKAN
from tfkan.layers import Conv2DKAN
from tfkan.layers import base

# %% [markdown]
# ## 30 SRM filters for preprocessing and the activation function

# %%
################################################## 30 SRM FILTERS
srm_weights = np.load('SRM_Kernels.npy') 
biasSRM=numpy.ones(30)
print (srm_weights.shape)
################################################## TLU ACTIVATION FUNCTION
T3 = 3;
def Tanh3(x):
    tanh3 = K.tanh(x)*T3
    return tanh3
##################################################
# Out:
# (5, 5, 1, 30)

# %% [markdown]
# ## Functions

# %%
## DCT filters function

def make_DCT_filter():
    with tf.name_scope("DCT"):
        # Initialize DCT filters
        DCT_filter_n = np.zeros([5, 5, 1, 64])
        # Definition of 8x8 mesh grid
        XX, YY = np.meshgrid(range(5), range(5))
        # DCT basis as filters
        C=np.ones(5)
        C[0]=1/np.sqrt(2)
        for v in range(5):
            for u in range(5):
                DCT_filter_n[:, :, 0, u+v*5]=(2*C[v]*C[u]/5)*np.cos((2*YY+1)*v*np.pi/(10))*np.cos((2*XX+1)*u*np.pi/(10))

        DCT_filter=tf.constant(DCT_filter_n.astype(np.float32))

        return DCT_filter

def Fun(x):
    fun = tf.keras.activations.hard_sigmoid(x)*3
    return fun

def squeeze_excitation_layer(input_layer, out_dim, ratio, conv):
  squeeze = tf.keras.layers.GlobalAveragePooling2D()(input_layer)
  excitation = tf.keras.layers.Dense(units=out_dim / ratio, activation='relu')(squeeze)
  excitation = tf.keras.layers.Dense(out_dim,activation='sigmoid')(excitation)
  excitation = tf.reshape(excitation, [-1,1,1,out_dim])
  scale = tf.keras.layers.multiply([input_layer, excitation])
  
  if conv:
    shortcut = tf.keras.layers.Conv2D(out_dim,kernel_size=1,strides=1,
                                      padding='same',kernel_initializer='he_normal')(input_layer)
    shortcut = tf.keras.layers.BatchNormalization()(shortcut)
  else:
    shortcut = input_layer
  out = tf.keras.layers.add([shortcut, scale])
  return out

# %% [markdown]
# ## Xu-Net architecture

# %%
def Xu_Net_strategy():
    
    img_size=256
    
    DCT_filter = make_DCT_filter()
    print(DCT_filter.shape)

    filters = np.concatenate([DCT_filter,srm_weights],axis=3)
    filters.shape
    
    bias = np.ones(94)

    tf.keras.backend.clear_session()
    inputs = tf.keras.Input(shape=(img_size,img_size,1), name="input")
    # Layer 1
    #conv0 =   tf.keras.layers.Conv2D(94, (5,5), weights=[filters,bias], strides=(1,1), trainable=False, activation=Tanh3, use_bias=True)(inputs)

    #Block 1
    layers_ty = tf.keras.layers.Conv2D(30, (5,5), weights=[srm_weights,biasSRM], strides=(1,1), trainable=False, padding='same', activation=Tanh3, use_bias=True)(inputs)
    layers_tn = tf.keras.layers.Conv2D(30, (5,5), weights=[srm_weights,biasSRM], strides=(1,1), trainable=True, padding='same', activation=Tanh3, use_bias=True)(inputs)
    layers1 = tf.keras.layers.add([layers_ty, layers_tn])

    layers = tf.keras.layers.Conv2D(30, (1,1), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers1) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
  
    layers = tf.keras.layers.Conv2D(30, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)

    layers = tf.keras.layers.Conv2D(30, (1,1), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    block_squeeze = squeeze_excitation_layer(layers, out_dim=30, ratio=32.0, conv=False)

    layers_Tr_1 = tf.keras.layers.add([layers1, block_squeeze])

    layers = tf.keras.layers.SpatialDropout2D(rate=0.1)(layers_Tr_1)
    layers = tf.keras.layers.Conv2D(32, (5,5), strides=(5,5),padding="same")(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = AveragePooling2D((5,5), strides= 1, padding='same')(layers)

    layers = tf.keras.layers.SpatialDropout2D(rate=0.1)(layers)
    layers = tf.keras.layers.Conv2D(32, (5,5), strides=(5,5),padding="same")(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    #layers = AveragePooling2D((3,3), strides= 1, padding='same')(layers)

    layers = GlobalAveragePooling2D(data_format="channels_last")(layers)

    #FC
    layers = DenseKAN(8)(layers)
    layers = DenseKAN(4)(layers)

    #Layer 18
    layers = DenseKAN(2)(layers)
    #Layer 19
    predictions = tf.keras.layers.Softmax(axis=1)(layers)
    model =tf.keras.Model(inputs = inputs, outputs=predictions)

    #Compile
    optimizer = tf.keras.optimizers.SGD(learning_rate=0.005, momentum=0.95)
    
    if compile:
        model.compile(optimizer= optimizer,
                      loss='binary_crossentropy',
                      metrics=['accuracy'])
        print ("kan_model")
    return model

# %%
model = Xu_Net_strategy()
model.summary()
# Out:
# (5, 5, 1, 64)
# kan_model
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 30  780         ['input[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 30  780         ['input[0][0]']
#                                 )
#
#  add (Add)                      (None, 256, 256, 30  0           ['conv2d[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 30  930         ['add[0][0]']
#                                 )
#
#  re_lu (ReLU)                   (None, 256, 256, 30  0           ['conv2d_2[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 30  120        ['re_lu[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 30  8130        ['batch_normalization[0][0]']
#                                 )
#
#  re_lu_1 (ReLU)                 (None, 256, 256, 30  0           ['conv2d_3[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 30  120        ['re_lu_1[0][0]']
#  rmalization)                   )
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 30  930         ['batch_normalization_1[0][0]']
#                                 )
#
#  re_lu_2 (ReLU)                 (None, 256, 256, 30  0           ['conv2d_4[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 30  120        ['re_lu_2[0][0]']
#  rmalization)                   )
#
#  global_average_pooling2d (Glob  (None, 30)          0           ['batch_normalization_2[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 0)            0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 30)           30          ['dense[0][0]']
#
#  tf.reshape (TFOpLambda)        (None, 1, 1, 30)     0           ['dense_1[0][0]']
#
#  multiply (Multiply)            (None, 256, 256, 30  0           ['batch_normalization_2[0][0]',
#                                 )                                 'tf.reshape[0][0]']
#
#  add_1 (Add)                    (None, 256, 256, 30  0           ['batch_normalization_2[0][0]',
#                                 )                                 'multiply[0][0]']
#
#  add_2 (Add)                    (None, 256, 256, 30  0           ['add[0][0]',
#                                 )                                 'add_1[0][0]']
#
#  spatial_dropout2d (SpatialDrop  (None, 256, 256, 30  0          ['add_2[0][0]']
#  out2D)                         )
#
#  conv2d_5 (Conv2D)              (None, 52, 52, 32)   24032       ['spatial_dropout2d[0][0]']
#
#  lambda (Lambda)                (None, 52, 52, 32)   0           ['conv2d_5[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 52, 52, 32)  128         ['lambda[0][0]']
#  rmalization)
#
#  average_pooling2d (AveragePool  (None, 52, 52, 32)  0           ['batch_normalization_3[0][0]']
#  ing2D)
#
#  spatial_dropout2d_1 (SpatialDr  (None, 52, 52, 32)  0           ['average_pooling2d[0][0]']
#  opout2D)
#
#  conv2d_6 (Conv2D)              (None, 11, 11, 32)   25632       ['spatial_dropout2d_1[0][0]']
#
#  lambda_1 (Lambda)              (None, 11, 11, 32)   0           ['conv2d_6[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 11, 11, 32)  128         ['lambda_1[0][0]']
#  rmalization)
#
#  global_average_pooling2d_1 (Gl  (None, 32)          0           ['batch_normalization_4[0][0]']
#  obalAveragePooling2D)
#
#  dense_kan (DenseKAN)           (None, 8)            2696        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_kan_1 (DenseKAN)         (None, 4)            388         ['dense_kan[0][0]']
#
#  dense_kan_2 (DenseKAN)         (None, 2)            122         ['dense_kan_1[0][0]']
#
#  softmax (Softmax)              (None, 2)            0           ['dense_kan_2[0][0]']
#
# ==================================================================================================
# Total params: 65,066
# Trainable params: 63,450
# Non-trainable params: 1,616
# __________________________________________________________________________________________________

# %% [markdown]
# ## Defining different functions to work with the architecture

# %%
def train(model, X_train, y_train, X_valid, y_valid, X_test, y_test, batch_size, epochs, initial_epoch = 0, model_name="", num_test=""):
    start_time = tm.time()
    log_dir="D:/testing_"+num_test+"/"+model_name+"_"+"{}".format(time())
    tensorboard = tf.keras.callbacks.TensorBoard(log_dir)
    filepath = log_dir+"/saved-model.hdf5"
    checkpoint = tf.keras.callbacks.ModelCheckpoint(
        filepath, 
        monitor='val_accuracy', 
        save_best_only=True, 
        mode='max',
        verbose=1
    )
    model.reset_states()
    history=model.fit(X_train, y_train, epochs=epochs, 
                        callbacks=[tensorboard,  checkpoint], 
                        batch_size=batch_size,
                        validation_data=(X_valid, y_valid),
                        initial_epoch=initial_epoch)
    
    metrics = model.evaluate(X_test, y_test, verbose=0)
    results_dir="D:/testing_"+num_test+"/"+model_name+"/"
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
      
        plt.figure(figsize=(10, 10))
        #plt.subplot(1,2,1)
        #Plot training & validation accuracy values
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('Accuracy Vs Epochs')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.grid('on')
        plt.savefig(results_dir+'Accuracy_Xu_Net_'+model_name+'.eps', format='eps')
        plt.savefig(results_dir+'Accuracy_Xu_Net_'+model_name+'.svg', format='svg')
        plt.savefig(results_dir+'Accuracy_Xu_Net_'+model_name+'.pdf', format='pdf')
        plt.show()
        
        plt.figure(figsize=(10, 10))
        #plt.subplot(1,2,2)
        #Plot training & validation loss values
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('Loss Vs Epochs')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.grid('on')
        plt.savefig(results_dir+'Loss_Xu_Net_'+model_name+'.eps', format='eps')
        plt.savefig(results_dir+'Loss_Xu_Net_'+model_name+'.svg', format='svg')
        plt.savefig(results_dir+'Loss_Xu_Net_'+model_name+'.pdf', format='pdf')
        plt.show()

    TIME = tm.time() - start_time
    print("Time "+model_name+" = %s [seconds]" % TIME)
    return {k:v for k,v in zip (model.metrics_names, metrics)}

# %%
def Final_Results_Test(model,filename):

    if filename != ('train') and filename != ('validation'):
        print("\n\nBest")
        print(filename)
        model.load_weights(filename)
        loss,accuracy = model.evaluate(X_test, y_test,verbose=0)
        print(f'Loss={loss:.4f} y Accuracy={accuracy:0.4f}'+'\n')

# %% [markdown]
# ## Working with BOSSbase 1.01 WOW y PAYLOAD = 0.4bpp

# %% [markdown]
# In the README, there is a link to download the databases we use for the work. There are two databases BOSSbase 1.01 and Bows2+ BOSSbase 1.01, cover images and stego. You can choose the payload of 0.2 and 0.4 bpp for each of the databases.

# %%
#Train
X_train = np.load('data_load\X_train.npy')
y_train = np.load('data_load\y_train.npy')
#Valid
X_valid = np.load('data_load\X_valid.npy')
y_valid = np.load('data_load\y_valid.npy')
#Test
X_test = np.load('data_load\X_test.npy')
y_test = np.load('data_load\y_test.npy')

print(X_train.shape)
print(y_train.shape)
print(X_valid.shape)
print(y_valid.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (8000, 256, 256, 1)
# (8000, 2)
# (2000, 256, 256, 1)
# (2000, 2)
# (10000, 256, 256, 1)
# (10000, 2)

# %% [markdown]
# ## CNN name and algorithm

# %%
base_name="04S-UNIWARD"
m_name="kan_strategy"

# %% [markdown]
# ## Training

# %%
model= Xu_Net_strategy() 
name="Model_"+m_name+"_"+base_name
_, history  = train(model, X_train, y_train, X_valid, y_valid, X_test, y_test, batch_size=4, epochs=150, model_name=name, num_test='3')
# Out:
# (5, 5, 1, 64)
# kan_model
# Epoch 1/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.7053 - accuracy: 0.5025
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 55s 26ms/step - loss: 0.7053 - accuracy: 0.5026 - val_loss: 0.7038 - val_accuracy: 0.5000
# Epoch 2/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7039 - accuracy: 0.5106
# Epoch 2: val_accuracy did not improve from 0.50000
# 2000/2000 [==============================] - 51s 25ms/step - loss: 0.7039 - accuracy: 0.5106 - val_loss: 0.7184 - val_accuracy: 0.5000
# Epoch 3/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7049 - accuracy: 0.4959
# Epoch 3: val_accuracy did not improve from 0.50000
# 2000/2000 [==============================] - 51s 25ms/step - loss: 0.7049 - accuracy: 0.4959 - val_loss: 0.7037 - val_accuracy: 0.5000
# Epoch 4/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.7027 - accuracy: 0.4979
# Epoch 4: val_accuracy did not improve from 0.50000
# 2000/2000 [==============================] - 51s 25ms/step - loss: 0.7027 - accuracy: 0.4981 - val_loss: 0.6998 - val_accuracy: 0.5000
# Epoch 5/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7026 - accuracy: 0.5015
# Epoch 5: val_accuracy improved from 0.50000 to 0.51450, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 51s 26ms/step - loss: 0.7026 - accuracy: 0.5015 - val_loss: 0.6982 - val_accuracy: 0.5145
# Epoch 6/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.7016 - accuracy: 0.4986
# Epoch 6: val_accuracy improved from 0.51450 to 0.51850, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 51s 26ms/step - loss: 0.7016 - accuracy: 0.4986 - val_loss: 0.6979 - val_accuracy: 0.5185
# Epoch 7/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7019 - accuracy: 0.4915
# Epoch 7: val_accuracy did not improve from 0.51850
# 2000/2000 [==============================] - 51s 26ms/step - loss: 0.7019 - accuracy: 0.4915 - val_loss: 0.6999 - val_accuracy: 0.5000
# Epoch 8/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7013 - accuracy: 0.5023
# Epoch 8: val_accuracy did not improve from 0.51850
# 2000/2000 [==============================] - 51s 26ms/step - loss: 0.7013 - accuracy: 0.5023 - val_loss: 0.6948 - val_accuracy: 0.5165
# Epoch 9/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.7009 - accuracy: 0.5071
# Epoch 9: val_accuracy improved from 0.51850 to 0.52000, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 51s 26ms/step - loss: 0.7009 - accuracy: 0.5074 - val_loss: 0.6967 - val_accuracy: 0.5200
# Epoch 10/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.7004 - accuracy: 0.4984
# Epoch 10: val_accuracy did not improve from 0.52000
# 2000/2000 [==============================] - 51s 26ms/step - loss: 0.7004 - accuracy: 0.4984 - val_loss: 0.6966 - val_accuracy: 0.5140
# Epoch 11/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.6990 - accuracy: 0.5160
# Epoch 11: val_accuracy improved from 0.52000 to 0.52550, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6990 - accuracy: 0.5163 - val_loss: 0.6950 - val_accuracy: 0.5255
# Epoch 12/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.6986 - accuracy: 0.5039
# Epoch 12: val_accuracy did not improve from 0.52550
# 2000/2000 [==============================] - 51s 26ms/step - loss: 0.6986 - accuracy: 0.5038 - val_loss: 0.6921 - val_accuracy: 0.5195
# Epoch 13/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6975 - accuracy: 0.5124
# Epoch 13: val_accuracy improved from 0.52550 to 0.54050, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 51s 26ms/step - loss: 0.6975 - accuracy: 0.5124 - val_loss: 0.6911 - val_accuracy: 0.5405
# Epoch 14/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.6954 - accuracy: 0.5284
# Epoch 14: val_accuracy improved from 0.54050 to 0.57350, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.6954 - accuracy: 0.5286 - val_loss: 0.6753 - val_accuracy: 0.5735
# Epoch 15/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.6915 - accuracy: 0.5343
# Epoch 15: val_accuracy improved from 0.57350 to 0.58950, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.6915 - accuracy: 0.5344 - val_loss: 0.6613 - val_accuracy: 0.5895
# Epoch 16/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6876 - accuracy: 0.5475
# Epoch 16: val_accuracy did not improve from 0.58950
# 2000/2000 [==============================] - 51s 26ms/step - loss: 0.6876 - accuracy: 0.5475 - val_loss: 0.6656 - val_accuracy: 0.5820
# Epoch 17/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.6832 - accuracy: 0.5546
# Epoch 17: val_accuracy did not improve from 0.58950
# 2000/2000 [==============================] - 51s 26ms/step - loss: 0.6832 - accuracy: 0.5545 - val_loss: 0.6696 - val_accuracy: 0.5785
# Epoch 18/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6799 - accuracy: 0.5515
# Epoch 18: val_accuracy did not improve from 0.58950
# 2000/2000 [==============================] - 51s 26ms/step - loss: 0.6799 - accuracy: 0.5515 - val_loss: 0.6702 - val_accuracy: 0.5770
# Epoch 19/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6728 - accuracy: 0.5695
# Epoch 19: val_accuracy did not improve from 0.58950
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6728 - accuracy: 0.5695 - val_loss: 0.7303 - val_accuracy: 0.5255
# Epoch 20/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6713 - accuracy: 0.5689
# Epoch 20: val_accuracy did not improve from 0.58950
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6713 - accuracy: 0.5689 - val_loss: 0.7097 - val_accuracy: 0.5700
# Epoch 21/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.6685 - accuracy: 0.5721
# Epoch 21: val_accuracy did not improve from 0.58950
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6685 - accuracy: 0.5720 - val_loss: 0.6524 - val_accuracy: 0.5625
# Epoch 22/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6621 - accuracy: 0.5840
# Epoch 22: val_accuracy improved from 0.58950 to 0.60950, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6621 - accuracy: 0.5840 - val_loss: 0.6299 - val_accuracy: 0.6095
# Epoch 23/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.6552 - accuracy: 0.5875
# Epoch 23: val_accuracy did not improve from 0.60950
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6552 - accuracy: 0.5876 - val_loss: 0.6371 - val_accuracy: 0.5870
# Epoch 24/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.6559 - accuracy: 0.5833
# Epoch 24: val_accuracy improved from 0.60950 to 0.62800, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6559 - accuracy: 0.5832 - val_loss: 0.6068 - val_accuracy: 0.6280
# Epoch 25/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.6420 - accuracy: 0.5915
# Epoch 25: val_accuracy did not improve from 0.62800
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6420 - accuracy: 0.5915 - val_loss: 0.6019 - val_accuracy: 0.6265
# Epoch 26/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6410 - accuracy: 0.5996
# Epoch 26: val_accuracy improved from 0.62800 to 0.63800, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6410 - accuracy: 0.5996 - val_loss: 0.5857 - val_accuracy: 0.6380
# Epoch 27/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.6343 - accuracy: 0.6144
# Epoch 27: val_accuracy improved from 0.63800 to 0.64700, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6344 - accuracy: 0.6141 - val_loss: 0.6035 - val_accuracy: 0.6470
# Epoch 28/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.6363 - accuracy: 0.6036
# Epoch 28: val_accuracy did not improve from 0.64700
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6362 - accuracy: 0.6036 - val_loss: 0.6440 - val_accuracy: 0.6225
# Epoch 29/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.6224 - accuracy: 0.6139
# Epoch 29: val_accuracy did not improve from 0.64700
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6226 - accuracy: 0.6137 - val_loss: 0.6324 - val_accuracy: 0.6400
# Epoch 30/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.6273 - accuracy: 0.6164
# Epoch 30: val_accuracy improved from 0.64700 to 0.67350, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6275 - accuracy: 0.6162 - val_loss: 0.5681 - val_accuracy: 0.6735
# Epoch 31/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6126 - accuracy: 0.6200
# Epoch 31: val_accuracy did not improve from 0.67350
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.6126 - accuracy: 0.6200 - val_loss: 0.5790 - val_accuracy: 0.6235
# Epoch 32/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6136 - accuracy: 0.6124
# Epoch 32: val_accuracy did not improve from 0.67350
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6136 - accuracy: 0.6124 - val_loss: 0.5820 - val_accuracy: 0.6120
# Epoch 33/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.6164 - accuracy: 0.6177
# Epoch 33: val_accuracy improved from 0.67350 to 0.69600, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6163 - accuracy: 0.6179 - val_loss: 0.5401 - val_accuracy: 0.6960
# Epoch 34/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6103 - accuracy: 0.6309
# Epoch 34: val_accuracy did not improve from 0.69600
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6103 - accuracy: 0.6309 - val_loss: 0.5435 - val_accuracy: 0.6595
# Epoch 35/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.6045 - accuracy: 0.6407
# Epoch 35: val_accuracy did not improve from 0.69600
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6044 - accuracy: 0.6409 - val_loss: 0.5573 - val_accuracy: 0.6435
# Epoch 36/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6079 - accuracy: 0.6266
# Epoch 36: val_accuracy did not improve from 0.69600
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6079 - accuracy: 0.6266 - val_loss: 0.6090 - val_accuracy: 0.6025
# Epoch 37/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.6079 - accuracy: 0.6266
# Epoch 37: val_accuracy did not improve from 0.69600
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6079 - accuracy: 0.6265 - val_loss: 0.5170 - val_accuracy: 0.6920
# Epoch 38/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.6040 - accuracy: 0.6251
# Epoch 38: val_accuracy did not improve from 0.69600
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6039 - accuracy: 0.6250 - val_loss: 0.6667 - val_accuracy: 0.5850
# Epoch 39/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5975 - accuracy: 0.6396
# Epoch 39: val_accuracy did not improve from 0.69600
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5974 - accuracy: 0.6399 - val_loss: 0.5796 - val_accuracy: 0.6305
# Epoch 40/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5998 - accuracy: 0.6349
# Epoch 40: val_accuracy did not improve from 0.69600
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5998 - accuracy: 0.6350 - val_loss: 0.5530 - val_accuracy: 0.6805
# Epoch 41/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5952 - accuracy: 0.6413
# Epoch 41: val_accuracy improved from 0.69600 to 0.69850, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5953 - accuracy: 0.6413 - val_loss: 0.5387 - val_accuracy: 0.6985
# Epoch 42/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.6024 - accuracy: 0.6404
# Epoch 42: val_accuracy did not improve from 0.69850
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.6022 - accuracy: 0.6406 - val_loss: 0.5652 - val_accuracy: 0.6900
# Epoch 43/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5985 - accuracy: 0.6344
# Epoch 43: val_accuracy did not improve from 0.69850
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5986 - accuracy: 0.6342 - val_loss: 0.5845 - val_accuracy: 0.6560
# Epoch 44/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5992 - accuracy: 0.6361
# Epoch 44: val_accuracy did not improve from 0.69850
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5991 - accuracy: 0.6360 - val_loss: 0.6341 - val_accuracy: 0.5605
# Epoch 45/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5912 - accuracy: 0.6451
# Epoch 45: val_accuracy did not improve from 0.69850
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5912 - accuracy: 0.6451 - val_loss: 0.6048 - val_accuracy: 0.6465
# Epoch 46/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5936 - accuracy: 0.6472
# Epoch 46: val_accuracy did not improve from 0.69850
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5938 - accuracy: 0.6470 - val_loss: 0.8343 - val_accuracy: 0.6490
# Epoch 47/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5890 - accuracy: 0.6489
# Epoch 47: val_accuracy did not improve from 0.69850
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5890 - accuracy: 0.6489 - val_loss: 0.5399 - val_accuracy: 0.6855
# Epoch 48/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5909 - accuracy: 0.6473
# Epoch 48: val_accuracy improved from 0.69850 to 0.71100, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 49s 25ms/step - loss: 0.5909 - accuracy: 0.6474 - val_loss: 0.5316 - val_accuracy: 0.7110
# Epoch 49/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5886 - accuracy: 0.6565
# Epoch 49: val_accuracy did not improve from 0.71100
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5886 - accuracy: 0.6565 - val_loss: 0.8643 - val_accuracy: 0.6105
# Epoch 50/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5910 - accuracy: 0.6447
# Epoch 50: val_accuracy did not improve from 0.71100
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5910 - accuracy: 0.6447 - val_loss: 0.7045 - val_accuracy: 0.6660
# Epoch 51/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5879 - accuracy: 0.6473
# Epoch 51: val_accuracy did not improve from 0.71100
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5879 - accuracy: 0.6474 - val_loss: 0.5485 - val_accuracy: 0.6850
# Epoch 52/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5900 - accuracy: 0.6494
# Epoch 52: val_accuracy did not improve from 0.71100
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5900 - accuracy: 0.6494 - val_loss: 0.6386 - val_accuracy: 0.6605
# Epoch 53/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5853 - accuracy: 0.6528
# Epoch 53: val_accuracy did not improve from 0.71100
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5852 - accuracy: 0.6528 - val_loss: 0.5390 - val_accuracy: 0.6940
# Epoch 54/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5961 - accuracy: 0.6441
# Epoch 54: val_accuracy did not improve from 0.71100
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5961 - accuracy: 0.6442 - val_loss: 0.5579 - val_accuracy: 0.6525
# Epoch 55/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5883 - accuracy: 0.6444
# Epoch 55: val_accuracy did not improve from 0.71100
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5883 - accuracy: 0.6444 - val_loss: 0.5398 - val_accuracy: 0.6905
# Epoch 56/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5842 - accuracy: 0.6578
# Epoch 56: val_accuracy did not improve from 0.71100
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5843 - accuracy: 0.6579 - val_loss: 0.5691 - val_accuracy: 0.6585
# Epoch 57/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5851 - accuracy: 0.6545
# Epoch 57: val_accuracy did not improve from 0.71100
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5850 - accuracy: 0.6546 - val_loss: 0.5522 - val_accuracy: 0.6785
# Epoch 58/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5835 - accuracy: 0.6482
# Epoch 58: val_accuracy did not improve from 0.71100
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5835 - accuracy: 0.6482 - val_loss: 0.5714 - val_accuracy: 0.6420
# Epoch 59/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5881 - accuracy: 0.6411
# Epoch 59: val_accuracy did not improve from 0.71100
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5881 - accuracy: 0.6411 - val_loss: 0.6041 - val_accuracy: 0.6205
# Epoch 60/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5889 - accuracy: 0.6496
# Epoch 60: val_accuracy did not improve from 0.71100
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5888 - accuracy: 0.6497 - val_loss: 0.5471 - val_accuracy: 0.6775
# Epoch 61/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5835 - accuracy: 0.6511
# Epoch 61: val_accuracy did not improve from 0.71100
# 2000/2000 [==============================] - 51s 26ms/step - loss: 0.5835 - accuracy: 0.6511 - val_loss: 0.5479 - val_accuracy: 0.6775
# Epoch 62/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5916 - accuracy: 0.6534
# Epoch 62: val_accuracy did not improve from 0.71100
# 2000/2000 [==============================] - 51s 25ms/step - loss: 0.5916 - accuracy: 0.6534 - val_loss: 0.6262 - val_accuracy: 0.6380
# Epoch 63/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5861 - accuracy: 0.6527
# Epoch 63: val_accuracy did not improve from 0.71100
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5861 - accuracy: 0.6528 - val_loss: 0.5591 - val_accuracy: 0.6925
# Epoch 64/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5860 - accuracy: 0.6575
# Epoch 64: val_accuracy improved from 0.71100 to 0.71400, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5859 - accuracy: 0.6575 - val_loss: 0.5379 - val_accuracy: 0.7140
# Epoch 65/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5853 - accuracy: 0.6585
# Epoch 65: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5854 - accuracy: 0.6585 - val_loss: 0.5961 - val_accuracy: 0.6605
# Epoch 66/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5801 - accuracy: 0.6562
# Epoch 66: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5800 - accuracy: 0.6562 - val_loss: 0.5407 - val_accuracy: 0.6965
# Epoch 67/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5785 - accuracy: 0.6607
# Epoch 67: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5785 - accuracy: 0.6607 - val_loss: 0.5579 - val_accuracy: 0.6770
# Epoch 68/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5835 - accuracy: 0.6506
# Epoch 68: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 51s 26ms/step - loss: 0.5835 - accuracy: 0.6506 - val_loss: 0.5187 - val_accuracy: 0.6925
# Epoch 69/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5849 - accuracy: 0.6574
# Epoch 69: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 51s 26ms/step - loss: 0.5851 - accuracy: 0.6572 - val_loss: 0.6178 - val_accuracy: 0.6425
# Epoch 70/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5801 - accuracy: 0.6539
# Epoch 70: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 51s 26ms/step - loss: 0.5801 - accuracy: 0.6539 - val_loss: 0.6907 - val_accuracy: 0.6520
# Epoch 71/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5821 - accuracy: 0.6505
# Epoch 71: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 51s 25ms/step - loss: 0.5821 - accuracy: 0.6505 - val_loss: 0.5478 - val_accuracy: 0.7020
# Epoch 72/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5853 - accuracy: 0.6499
# Epoch 72: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5854 - accuracy: 0.6500 - val_loss: 0.5177 - val_accuracy: 0.7025
# Epoch 73/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5872 - accuracy: 0.6379
# Epoch 73: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5872 - accuracy: 0.6379 - val_loss: 0.5818 - val_accuracy: 0.6605
# Epoch 74/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5773 - accuracy: 0.6613
# Epoch 74: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5773 - accuracy: 0.6614 - val_loss: 0.5965 - val_accuracy: 0.6880
# Epoch 75/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5836 - accuracy: 0.6521
# Epoch 75: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5836 - accuracy: 0.6521 - val_loss: 0.6227 - val_accuracy: 0.6465
# Epoch 76/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5810 - accuracy: 0.6588
# Epoch 76: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5809 - accuracy: 0.6589 - val_loss: 0.7510 - val_accuracy: 0.6415
# Epoch 77/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5846 - accuracy: 0.6493
# Epoch 77: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5846 - accuracy: 0.6491 - val_loss: 0.8075 - val_accuracy: 0.5700
# Epoch 78/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5812 - accuracy: 0.6553
# Epoch 78: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 48s 24ms/step - loss: 0.5812 - accuracy: 0.6553 - val_loss: 0.6121 - val_accuracy: 0.6020
# Epoch 79/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5848 - accuracy: 0.6416
# Epoch 79: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 51s 25ms/step - loss: 0.5847 - accuracy: 0.6417 - val_loss: 0.5583 - val_accuracy: 0.6650
# Epoch 80/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5874 - accuracy: 0.6531
# Epoch 80: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5874 - accuracy: 0.6531 - val_loss: 0.5748 - val_accuracy: 0.6525
# Epoch 81/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5831 - accuracy: 0.6526
# Epoch 81: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5831 - accuracy: 0.6525 - val_loss: 0.6263 - val_accuracy: 0.6025
# Epoch 82/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5866 - accuracy: 0.6553
# Epoch 82: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5865 - accuracy: 0.6555 - val_loss: 0.5478 - val_accuracy: 0.6870
# Epoch 83/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5833 - accuracy: 0.6546
# Epoch 83: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5833 - accuracy: 0.6546 - val_loss: 0.6295 - val_accuracy: 0.6820
# Epoch 84/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5834 - accuracy: 0.6541
# Epoch 84: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5834 - accuracy: 0.6541 - val_loss: 0.5671 - val_accuracy: 0.6540
# Epoch 85/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5842 - accuracy: 0.6570
# Epoch 85: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5842 - accuracy: 0.6570 - val_loss: 0.5666 - val_accuracy: 0.6780
# Epoch 86/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5747 - accuracy: 0.6603
# Epoch 86: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5747 - accuracy: 0.6600 - val_loss: 0.5513 - val_accuracy: 0.6970
# Epoch 87/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5822 - accuracy: 0.6481
# Epoch 87: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5821 - accuracy: 0.6482 - val_loss: 0.5450 - val_accuracy: 0.6770
# Epoch 88/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5749 - accuracy: 0.6652
# Epoch 88: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5748 - accuracy: 0.6653 - val_loss: 0.5879 - val_accuracy: 0.6390
# Epoch 89/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5770 - accuracy: 0.6563
# Epoch 89: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5770 - accuracy: 0.6564 - val_loss: 0.5697 - val_accuracy: 0.6850
# Epoch 90/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5759 - accuracy: 0.6653
# Epoch 90: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5759 - accuracy: 0.6653 - val_loss: 0.5364 - val_accuracy: 0.6950
# Epoch 91/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5800 - accuracy: 0.6563
# Epoch 91: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 51s 25ms/step - loss: 0.5799 - accuracy: 0.6564 - val_loss: 0.5177 - val_accuracy: 0.7045
# Epoch 92/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5751 - accuracy: 0.6647
# Epoch 92: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 49s 25ms/step - loss: 0.5750 - accuracy: 0.6647 - val_loss: 0.6079 - val_accuracy: 0.6960
# Epoch 93/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5739 - accuracy: 0.6612
# Epoch 93: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5738 - accuracy: 0.6611 - val_loss: 0.8534 - val_accuracy: 0.6540
# Epoch 94/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5788 - accuracy: 0.6598
# Epoch 94: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.5788 - accuracy: 0.6599 - val_loss: 0.6298 - val_accuracy: 0.6575
# Epoch 95/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5816 - accuracy: 0.6586
# Epoch 95: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.5816 - accuracy: 0.6586 - val_loss: 0.5278 - val_accuracy: 0.6900
# Epoch 96/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5796 - accuracy: 0.6534
# Epoch 96: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5796 - accuracy: 0.6534 - val_loss: 0.5998 - val_accuracy: 0.6220
# Epoch 97/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5810 - accuracy: 0.6557
# Epoch 97: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.5810 - accuracy: 0.6556 - val_loss: 0.5450 - val_accuracy: 0.6900
# Epoch 98/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5763 - accuracy: 0.6617
# Epoch 98: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.5762 - accuracy: 0.6618 - val_loss: 0.6056 - val_accuracy: 0.6230
# Epoch 99/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5674 - accuracy: 0.6729
# Epoch 99: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5674 - accuracy: 0.6729 - val_loss: 0.5800 - val_accuracy: 0.6745
# Epoch 100/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5760 - accuracy: 0.6634
# Epoch 100: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5759 - accuracy: 0.6635 - val_loss: 0.5272 - val_accuracy: 0.6970
# Epoch 101/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5766 - accuracy: 0.6654
# Epoch 101: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5767 - accuracy: 0.6653 - val_loss: 0.5969 - val_accuracy: 0.6080
# Epoch 102/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5749 - accuracy: 0.6667
# Epoch 102: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5749 - accuracy: 0.6666 - val_loss: 0.5400 - val_accuracy: 0.7125
# Epoch 103/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5733 - accuracy: 0.6636
# Epoch 103: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5733 - accuracy: 0.6636 - val_loss: 0.6395 - val_accuracy: 0.6030
# Epoch 104/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5736 - accuracy: 0.6605
# Epoch 104: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5734 - accuracy: 0.6606 - val_loss: 0.5758 - val_accuracy: 0.6900
# Epoch 105/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5741 - accuracy: 0.6622
# Epoch 105: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5741 - accuracy: 0.6622 - val_loss: 0.5450 - val_accuracy: 0.6900
# Epoch 106/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5824 - accuracy: 0.6604
# Epoch 106: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5824 - accuracy: 0.6604 - val_loss: 0.5700 - val_accuracy: 0.7135
# Epoch 107/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5738 - accuracy: 0.6595
# Epoch 107: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5737 - accuracy: 0.6596 - val_loss: 0.5805 - val_accuracy: 0.6565
# Epoch 108/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5742 - accuracy: 0.6572
# Epoch 108: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5742 - accuracy: 0.6572 - val_loss: 0.5771 - val_accuracy: 0.6770
# Epoch 109/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5768 - accuracy: 0.6638
# Epoch 109: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5768 - accuracy: 0.6637 - val_loss: 0.5420 - val_accuracy: 0.6915
# Epoch 110/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5762 - accuracy: 0.6578
# Epoch 110: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5761 - accuracy: 0.6578 - val_loss: 0.5773 - val_accuracy: 0.6950
# Epoch 111/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5748 - accuracy: 0.6648
# Epoch 111: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.5748 - accuracy: 0.6650 - val_loss: 0.5620 - val_accuracy: 0.7065
# Epoch 112/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5737 - accuracy: 0.6695
# Epoch 112: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.5738 - accuracy: 0.6694 - val_loss: 0.5300 - val_accuracy: 0.7085
# Epoch 113/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5735 - accuracy: 0.6617
# Epoch 113: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5736 - accuracy: 0.6615 - val_loss: 0.5630 - val_accuracy: 0.6830
# Epoch 114/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5727 - accuracy: 0.6615
# Epoch 114: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5728 - accuracy: 0.6618 - val_loss: 0.5255 - val_accuracy: 0.6910
# Epoch 115/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5774 - accuracy: 0.6662
# Epoch 115: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5774 - accuracy: 0.6662 - val_loss: 0.7002 - val_accuracy: 0.6065
# Epoch 116/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5782 - accuracy: 0.6655
# Epoch 116: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5783 - accuracy: 0.6654 - val_loss: 0.6652 - val_accuracy: 0.6755
# Epoch 117/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5794 - accuracy: 0.6596
# Epoch 117: val_accuracy did not improve from 0.71400
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5794 - accuracy: 0.6596 - val_loss: 0.6082 - val_accuracy: 0.6370
# Epoch 118/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5790 - accuracy: 0.6621
# Epoch 118: val_accuracy improved from 0.71400 to 0.72200, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5790 - accuracy: 0.6621 - val_loss: 0.5068 - val_accuracy: 0.7220
# Epoch 119/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5717 - accuracy: 0.6683
# Epoch 119: val_accuracy did not improve from 0.72200
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5717 - accuracy: 0.6683 - val_loss: 0.5795 - val_accuracy: 0.6405
# Epoch 120/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5797 - accuracy: 0.6599
# Epoch 120: val_accuracy did not improve from 0.72200
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5796 - accuracy: 0.6599 - val_loss: 0.5406 - val_accuracy: 0.6700
# Epoch 121/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5741 - accuracy: 0.6592
# Epoch 121: val_accuracy did not improve from 0.72200
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5740 - accuracy: 0.6594 - val_loss: 0.5385 - val_accuracy: 0.7040
# Epoch 122/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5731 - accuracy: 0.6686
# Epoch 122: val_accuracy did not improve from 0.72200
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5731 - accuracy: 0.6686 - val_loss: 0.6129 - val_accuracy: 0.6195
# Epoch 123/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5772 - accuracy: 0.6620
# Epoch 123: val_accuracy did not improve from 0.72200
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5772 - accuracy: 0.6620 - val_loss: 0.5222 - val_accuracy: 0.7005
# Epoch 124/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5730 - accuracy: 0.6655
# Epoch 124: val_accuracy did not improve from 0.72200
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5730 - accuracy: 0.6654 - val_loss: 0.5166 - val_accuracy: 0.7005
# Epoch 125/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5783 - accuracy: 0.6655
# Epoch 125: val_accuracy did not improve from 0.72200
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5783 - accuracy: 0.6655 - val_loss: 0.6007 - val_accuracy: 0.6645
# Epoch 126/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5699 - accuracy: 0.6682
# Epoch 126: val_accuracy did not improve from 0.72200
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5698 - accuracy: 0.6684 - val_loss: 0.6902 - val_accuracy: 0.6360
# Epoch 127/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5744 - accuracy: 0.6733
# Epoch 127: val_accuracy did not improve from 0.72200
# 2000/2000 [==============================] - 50s 25ms/step - loss: 0.5742 - accuracy: 0.6735 - val_loss: 0.5184 - val_accuracy: 0.7005
# Epoch 128/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5713 - accuracy: 0.6713
# Epoch 128: val_accuracy improved from 0.72200 to 0.72350, saving model to D:/testing_3/Model_kan_strategy_04S-UNIWARD_1729036243.6956654\saved-model.hdf5
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5714 - accuracy: 0.6712 - val_loss: 0.5146 - val_accuracy: 0.7235
# Epoch 129/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5687 - accuracy: 0.6739
# Epoch 129: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5687 - accuracy: 0.6739 - val_loss: 0.5135 - val_accuracy: 0.7015
# Epoch 130/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5709 - accuracy: 0.6625
# Epoch 130: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5709 - accuracy: 0.6625 - val_loss: 0.5197 - val_accuracy: 0.7105
# Epoch 131/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5744 - accuracy: 0.6657
# Epoch 131: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5747 - accuracy: 0.6654 - val_loss: 0.5454 - val_accuracy: 0.6825
# Epoch 132/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5698 - accuracy: 0.6613
# Epoch 132: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5697 - accuracy: 0.6615 - val_loss: 0.5827 - val_accuracy: 0.5970
# Epoch 133/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5713 - accuracy: 0.6730
# Epoch 133: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5715 - accuracy: 0.6730 - val_loss: 0.5902 - val_accuracy: 0.7140
# Epoch 134/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5690 - accuracy: 0.6657
# Epoch 134: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5692 - accuracy: 0.6653 - val_loss: 0.5837 - val_accuracy: 0.6720
# Epoch 135/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5695 - accuracy: 0.6711
# Epoch 135: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.5695 - accuracy: 0.6711 - val_loss: 0.5741 - val_accuracy: 0.6515
# Epoch 136/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5685 - accuracy: 0.6733
# Epoch 136: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.5685 - accuracy: 0.6733 - val_loss: 0.5564 - val_accuracy: 0.6695
# Epoch 137/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5739 - accuracy: 0.6604
# Epoch 137: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5738 - accuracy: 0.6606 - val_loss: 0.6161 - val_accuracy: 0.6560
# Epoch 138/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5702 - accuracy: 0.6670
# Epoch 138: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5702 - accuracy: 0.6670 - val_loss: 0.5696 - val_accuracy: 0.6890
# Epoch 139/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5664 - accuracy: 0.6704
# Epoch 139: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.5663 - accuracy: 0.6704 - val_loss: 0.6375 - val_accuracy: 0.6145
# Epoch 140/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5663 - accuracy: 0.6701
# Epoch 140: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.5662 - accuracy: 0.6701 - val_loss: 0.5318 - val_accuracy: 0.7060
# Epoch 141/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5713 - accuracy: 0.6639
# Epoch 141: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 53s 26ms/step - loss: 0.5713 - accuracy: 0.6639 - val_loss: 0.7600 - val_accuracy: 0.6265
# Epoch 142/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5745 - accuracy: 0.6666
# Epoch 142: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.5745 - accuracy: 0.6665 - val_loss: 0.5793 - val_accuracy: 0.6860
# Epoch 143/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5735 - accuracy: 0.6633
# Epoch 143: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.5734 - accuracy: 0.6634 - val_loss: 0.5433 - val_accuracy: 0.6865
# Epoch 144/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5687 - accuracy: 0.6639
# Epoch 144: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 51s 25ms/step - loss: 0.5687 - accuracy: 0.6639 - val_loss: 0.5571 - val_accuracy: 0.6945
# Epoch 145/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5753 - accuracy: 0.6667
# Epoch 145: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5754 - accuracy: 0.6665 - val_loss: 0.6413 - val_accuracy: 0.6310
# Epoch 146/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5744 - accuracy: 0.6695
# Epoch 146: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5744 - accuracy: 0.6694 - val_loss: 0.5807 - val_accuracy: 0.7175
# Epoch 147/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5668 - accuracy: 0.6748
# Epoch 147: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5671 - accuracy: 0.6745 - val_loss: 0.5687 - val_accuracy: 0.6895
# Epoch 148/150
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5665 - accuracy: 0.6721
# Epoch 148: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5665 - accuracy: 0.6721 - val_loss: 0.5627 - val_accuracy: 0.6640
# Epoch 149/150
# 1998/2000 [============================>.] - ETA: 0s - loss: 0.5707 - accuracy: 0.6723
# Epoch 149: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5706 - accuracy: 0.6722 - val_loss: 0.6088 - val_accuracy: 0.6995
# Epoch 150/150
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5643 - accuracy: 0.6728
# Epoch 150: val_accuracy did not improve from 0.72350
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.5643 - accuracy: 0.6727 - val_loss: 0.5528 - val_accuracy: 0.7050
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Time Model_kan_strategy_04S-UNIWARD = 7752.809308767319 [seconds]

# %% [markdown]
# ## Test

# %%
model= Xu_Net_strategy() 
PATH_trained_models = "D:\modelos\Model_XU_Net_04S-UNIWARD_1728342103.1582682\saved-model.hdf5"
Final_Results_Test(model,PATH_trained_models)
# Out:
# using 2 classes
# Xunet
#
#
# Best
# D:\modelos\Model_XU_Net_04S-UNIWARD_1728342103.1582682\saved-model.hdf5
# Loss=0.7837 y Accuracy=0.7031
